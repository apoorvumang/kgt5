# %%
import os
import pickle
from tqdm.notebook import tqdm
import networkx as nx

# %%
kg_name = 'fbwq_full_lego'

# %%
def loadTriples(fname):
    f = open(fname)
    triples = []
    for line in f:
        if not line.startswith('predict tail:'):
            continue
        line = line.rstrip()
        line = line.replace('predict tail: ', '')
        head_rel, tail = line.split('\t')
        head_rel = head_rel.replace(' | ', '\t')
        head_rel = head_rel[:-2]
        head, rel = head_rel.split('\t')
        triples.append([head, rel, tail])
    return triples

def getEntities(triples):
    ents = set()
    for t in triples:
        ents.add(t[0])
        ents.add(t[2])
    return ents

def getHeadFromInputString(s):
    s = s.split('|')[0][:-1]
    s = s.replace('predict answer: ', '')
    return s

# %%
fname = os.path.join('data', kg_name, 'train.txt')
train = loadTriples(fname)

# %%
entities = getEntities(train)
len(train), len(entities)
# Out:
# (752717, 149681)

# %%
G = nx.Graph()
G.add_nodes_from(entities)
for t in train:
    G.add_edge(t[0], t[2])

# %%
len(G)
# Out:
# 149681

# %%
fname = 'scores/scores_fbwq_lego_full.pickle'
# fname = 'scores_500_base_trie|.pickle'
scores_data = pickle.load(open(fname, 'rb'))

# %%
from collections import defaultdict
predictions_scores_dicts = []
for string_arr, score_arr in tqdm(zip(scores_data['prediction_strings'], scores_data['scores'])):
    ps_pairs = [(p,s) for p,s in zip(string_arr, score_arr)]
    ps_pairs = list(set(ps_pairs)) # while sampling, duplicates are created
    # remove predictions that are not entities
    ps_dict_only_entities = defaultdict(list)
    for ps in ps_pairs:
#         if ps[0] in entity_strings_set:
        ps_dict_only_entities[ps[0]] = ps[1].item()
    predictions_scores_dicts.append(ps_dict_only_entities)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…

# %%
predictions_scores_dicts[0]
# Out:
# defaultdict(list,
#             {'jamaican creole english language': -0.09705529361963272,
#              'jamaican spanish': -0.7353574633598328,
#              'jamaican sign language': -0.7613774538040161,
#              'jamaican english': -0.10564038157463074})

# %%
onehop_nbhoods = []
twohop_nbhoods = []
for i in tqdm(range(len(predictions_filtered))):
    input_string = scores_data['input_strings'][i]
    onehop = set()
    twohop = set()
    head = getHeadFromInputString(input_string)
    if head in G:
        onehop = set(G.neighbors(head))
        twohop = set(nx.single_source_shortest_path_length(G, head, cutoff=2))
    onehop_nbhoods.append(onehop)
    twohop_nbhoods.append(twohop)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1639.0), HTML(value='')))

# %%
import copy
from tqdm.notebook import tqdm
# do score reranking
predictions_filtered = copy.deepcopy(predictions_scores_dicts)
alpha = 1
for i in tqdm(range(len(predictions_filtered))):
    input_string = scores_data['input_strings'][i]
    head = getHeadFromInputString(input_string)
    if head not in G:
        print(input_string)
        continue
    nbhood = onehop_nbhoods[i]
    nbhood_2hop = twohop_nbhoods[i]
    for key in predictions_filtered[i].keys():
#         if key in nbhood:
#             predictions_filtered[i][key] += alpha
#             predictions_filtered[i][key] /= 10
        if key in nbhood_2hop:
            predictions_filtered[i][key] += alpha
#             predictions_filtered[i][key] /= 1.5
#     print(nbhood)
#     for j in range(len(predictions_filtered[i])):
#         print(predictions_filtered[j])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1639.0), HTML(value='')))
# predict answer: UNK | who plays blaine in NE
# predict answer: UNK | who did NE play for before arsenal
# predict answer: UNK | who plays NE
# predict answer: UNK | what does NE stand for
# predict answer: UNK | when was the last time the NE went to the stanley cup

# %%
predictions_filtered[0]
# Out:
# defaultdict(list,
#             {'jamaican creole english language': 0.9029447063803673,
#              'jamaican spanish': -0.7353574633598328,
#              'jamaican sign language': -0.7613774538040161,
#              'jamaican english': 0.8943596184253693})

# %%
num_correct = 0
ans_to_improve = []
for i in range(len(predictions_filtered)):
    target = scores_data['target_strings'][i]
    ps_dict = predictions_filtered[i]
    ps_sorted = sorted(ps_dict.items(), key=lambda item: -item[1])
    if len(ps_dict) == 0:
        preds = []
        best_pred = "NOT FOUND"
    else:
        preds = [x[0] for x in ps_sorted]
        best_pred = preds[0]
    if best_pred in target:
        num_correct += 1
    if best_pred not in target and len(set(preds).intersection(set(target))) > 0:
#         print(i)
        ans_to_improve.append(i)
        pass
print(num_correct/len(predictions_filtered))
# Out:
# 0.5613178767541184

# %%
id = ans_to_improve[4]
print(scores_data['input_strings'][id])
print(scores_data['target_strings'][id])
for k,v in predictions_filtered[id].items():
    print(k, predictions_scores_dicts[id][k])
print()
for k,v in predictions_filtered[id].items():
    print(k, v)
# Out:
# predict answer: german language | which countries speak NE officially
# ['belgium', 'germany', 'east germany', 'luxembourg', 'liechtenstein', 'switzerland', 'austria']
# united states of america -0.4664650857448578
# cyprus -0.5250051021575928
# czech republic -0.43854737281799316
# switzerland -0.45648112893104553
#
# united states of america 0.03353491425514221
# cyprus -0.025005102157592773
# czech republic 0.061452627182006836
# switzerland 0.04351887106895447

# %%
print(scores_data['input_strings'][id])
print(scores_data['target_strings'][id])
for k,v in predictions_scores_dicts[id].items():
    print(k, v)
# Out:
# predict answer: carl wilson | what kind of cancer did NE have |
# ['lung cancer', 'brain tumor']
# lung cancer -1.0429471731185913
# cardiac arrest -0.9492165446281433
# prostate cancer -0.8682568669319153
# pneumonia -0.38310763239860535

# %%
head = getHeadFromInputString(scores_data['input_strings'][id])
# set(G.neighbors(head))

# %%
nx.single_source_shortest_path_length(G, head, cutoff=2)
# Out:
# {'indonesia': 0,
#  '249865631': 1,
#  '178633239': 1,
#  'tulungagung regency': 1,
#  '200050444': 1,
#  '188019278': 1,
#  'eurasia': 1,
#  '221293797': 1,
#  '218145617': 1,
#  '132385413': 1,
#  '208938698': 1,
#  '123002081': 1,
#  '126080548': 1,
#  '243801639': 1,
#  'japanese occupation of the dutch east indies': 1,
#  '111187930': 1,
#  '159097735': 1,
#  '90860197': 1,
#  'sunda language': 1,
#  '224480901': 1,
#  'english language': 1,
#  '240676485': 1,
#  '172265107': 1,
#  '142156086': 1,
#  '169039084': 1,
#  'bali': 1,
#  'ngurah rai international airport': 1,
#  '211970371': 1,
#  'cibeureum, banjar, pandeglang': 1,
#  '93101152': 1,
#  'm.03xf2_w': 1,
#  '181786329': 1,
#  '138857752': 1,
#  'm.064szk2': 1,
#  '230972808': 1,
#  '102924506': 1,
#  '255461700': 1,
#  '135601258': 1,
#  '148872395': 1,
#  '175460614': 1,
#  '97828538': 1,
#  'trenggalek regency': 1,
#  '202990922': 1,
#  '234243489': 1,
#  '194112556': 1,
#  '114066887': 1,
#  '205946831': 1,
#  '105605766': 1,
#  '162458871': 1,
#  '129210098': 1,
#  '237424363': 1,
#  'bali language': 1,
#  'madura language': 1,
#  '88692697': 1,
#  '116996006': 1,
#  'belok': 1,
#  '191085673': 1,
#  '197097887': 1,
#  '100329810': 1,
#  'sulangai': 1,
#  '108364330': 1,
#  '237486894': 1,
#  'perintis': 1,
#  'javanese language': 1,
#  'operation rimau': 1,
#  '165772077': 1,
#  'jakarta': 1,
#  '95420835': 1,
#  'tobelo language': 1,
#  '246864191': 1,
#  '227709821': 1,
#  'm.064szjw': 1,
#  '145494452': 1,
#  '184916848': 1,
#  'tetun language': 1,
#  'pematang sapat': 1,
#  '155698247': 1,
#  '119974444': 1,
#  '215038285': 1,
#  '152280731': 1,
#  'm.03xf301': 1,
#  'batak language': 1,
#  'another time, another place': 2,
#  'dirk nowitzki': 2,
#  'naked movie': 2,
#  'bessie': 2,
#  'small fry': 2,
#  'across to singapore': 2,
#  'iceland': 2,
#  'flight of the navigator': 2,
#  "the last flight of noah's ark": 2,
#  'jay-z': 2,
#  'icon': 2,
#  'the outsider': 2,
#  'uganda': 2,
#  'the scream team': 2,
#  'billy dee williams': 2,
#  'arnold schwarzenegger': 2,
#  'texas chainsaw massacre: the next generation': 2,
#  'snow white and the seven dwarfs': 2,
#  'mixed nuts': 2,
#  'american samoa': 2,
#  'if lucy fell': 2,
#  'snipes': 2,
#  'levity': 2,
#  'miley cyrus: tongue tied': 2,
#  'mean people suck': 2,
#  "if you lived here, you'd be home now": 2,
#  'taxi': 2,
#  'tales of the black freighter': 2,
#  'glee encore': 2,
#  'the rescuers down under': 2,
#  'homo erectus': 2,
#  'inspector gadget': 2,
#  'the dog who saved christmas vacation': 2,
#  'macho callahan': 2,
#  'murder on the orient express': 2,
#  'juice': 2,
#  'eyewitness': 2,
#  'international atomic energy agency': 2,
#  'dirty deeds': 2,
#  'papua new guinea': 2,
#  'curious george 2: follow that monkey!': 2,
#  'daisy kenyon': 2,
#  'last knights': 2,
#  'the idle class': 2,
#  'bulun, tattinsky district, sakha republic': 2,
#  'cutlass': 2,
#  'the leading man': 2,
#  'norfolk island': 2,
#  'robot wrecks': 2,
#  'revolt in the big house': 2,
#  'rv': 2,
#  'avril lavigne': 2,
#  'shalako': 2,
#  'high noon, part ii: the return of will kane': 2,
#  'my beautiful laundrette': 2,
#  'jurassic park': 2,
#  '21 jump street': 2,
#  'grease': 2,
#  'holly hobbie and friends: christmas wishes': 2,
#  'flirting': 2,
#  'the burning plain': 2,
#  'a place in time': 2,
#  'scary movie 4': 2,
#  'the fever': 2,
#  'date movie': 2,
#  "a woman's face": 2,
#  'cinderella iii: a twist in time': 2,
#  'the cake eaters': 2,
#  'in the valley of elah': 2,
#  'beverly hills chihuahua 2': 2,
#  'brothers in arms': 2,
#  'grace of monaco': 2,
#  'judy garland': 2,
#  'kicking & screaming': 2,
#  'secretariat': 2,
#  'life support': 2,
#  'the pyx': 2,
#  'epic': 2,
#  'the new swiss family robinson': 2,
#  'american vampire': 2,
#  'beowulf': 2,
#  'birthday girl': 2,
#  '1944-10-10': 2,
#  'run the tide': 2,
#  'fiji': 2,
#  'taking lives': 2,
#  'blue valentine': 2,
#  'freeway': 2,
#  'the last days': 2,
#  'the waterboy': 2,
#  "lil' pimp": 2,
#  'four minutes': 2,
#  'the bachelor': 2,
#  'ghost world': 2,
#  'six days in paradise': 2,
#  'the first circle': 2,
#  'me, myself & irene': 2,
#  'just cause': 2,
#  '10 years': 2,
#  'eleanor and franklin: the white house years': 2,
#  'action of the tiger': 2,
#  'deadfall': 2,
#  'd.e.b.s.': 2,
#  'bad cop': 2,
#  'the spirit': 2,
#  'mimi rogers': 2,
#  "sanjay's super team": 2,
#  'african cats': 2,
#  'whacked!': 2,
#  'king of the grizzlies': 2,
#  'all good things': 2,
#  'the unbelievables': 2,
#  'paranoid park': 2,
#  'mr deeds': 2,
#  'wax on, f*ck off': 2,
#  'the rage': 2,
#  "ball don't lie": 2,
#  'twelve miles out': 2,
#  'three wishes': 2,
#  'rising son': 2,
#  'miracle dogs': 2,
#  'donnie darko': 2,
#  'the magic of belle isle': 2,
#  'northern cyprus': 2,
#  'baby blues': 2,
#  'stuck in love': 2,
#  'robots': 2,
#  'something to talk about': 2,
#  'green card': 2,
#  'captain eo': 2,
#  'conviction': 2,
#  'where the heart is': 2,
#  'the stepford wives': 2,
#  'the ugly truth': 2,
#  'the supremes in the orient': 2,
#  'nobody runs forever': 2,
#  'we are family': 2,
#  'shantaram': 2,
#  'garden party': 2,
#  'swaziland': 2,
#  'happy christmas': 2,
#  'tuvalu': 2,
#  'meet the spartans': 2,
#  'the family fang': 2,
#  'protestantism': 2,
#  'free to be... you and me': 2,
#  'sweeney todd': 2,
#  'what just happened': 2,
#  "happy mother's day, love george": 2,
#  'cosmic voyage': 2,
#  'national treasure': 2,
#  'the heart specialist': 2,
#  'timothy hutton': 2,
#  'disney princess stories: vol. 3: beauty shines from within': 2,
#  "mr. morgan's last love": 2,
#  'black sheep': 2,
#  'nine': 2,
#  'outland': 2,
#  'bewitched': 2,
#  "national lampoon's pledge this!": 2,
#  'the rules of attraction': 2,
#  'smooch': 2,
#  'grasshopper': 2,
#  'extreme realities': 2,
#  "doin' their bit": 2,
#  'persuasion': 2,
#  'anderson cooper': 2,
#  'getaway': 2,
#  'pitch perfect': 2,
#  'frost/nixon': 2,
#  'shrek 2': 2,
#  'oldboy': 2,
#  'closing the ring': 2,
#  'miley cyrus': 2,
#  "a doll's house": 2,
#  'calling all kids': 2,
#  'horton hears a who!': 2,
#  "max keeble's big move": 2,
#  'almost dead': 2,
#  'disney princess stories: vol. 1: a gift from the heart': 2,
#  'hong kong': 2,
#  'wilder days': 2,
#  'bridge of spies': 2,
#  'americana': 2,
#  'the return of the pink panther': 2,
#  'indiana jones and the temple of doom': 2,
#  'dogtown': 2,
#  'guess who': 2,
#  'torrance rises': 2,
#  'daredevil': 2,
#  'sing a song with pooh bear and piglet too: sing-along songs': 2,
#  'despicable me': 2,
#  'lethal dose': 2,
#  'tatooine': 2,
#  'new zealand': 2,
#  'nice and friendly': 2,
#  'school for scoundrels': 2,
#  'growing the big one': 2,
#  "the little mermaid: ariel's beginning": 2,
#  'repo! the genetic opera': 2,
#  'nothing too good for a cowboy': 2,
#  "the world's greatest athlete": 2,
#  'the sword in the stone': 2,
#  'rocknrolla': 2,
#  'oblivion': 2,
#  'killing mr. griffin': 2,
#  'sugar: the fall of the west': 2,
#  'd3: the mighty ducks': 2,
#  '30 days of night: dust to dust': 2,
#  'mortdecai': 2,
#  'the circle': 2,
#  'love on the run': 2,
#  '127 hours': 2,
#  '4 little girls': 2,
#  'silver blaze': 2,
#  'princess of thieves': 2,
#  'star trek into darkness': 2,
#  'butter': 2,
#  'the good lie': 2,
#  'walker, texas ranger: trial by fire': 2,
#  'the first nudie musical': 2,
#  'beyonce knowles': 2,
#  'fresh horses': 2,
#  'the donor': 2,
#  'the jerk theory': 2,
#  'cannes man': 2,
#  'x-men': 2,
#  "mr. magorium's wonder emporium": 2,
#  'lucas': 2,
#  'waxwork ii: lost in time': 2,
#  'let it snow': 2,
#  'the floorwalker': 2,
#  'camp rock 2: the final jam': 2,
#  'knowing': 2,
#  'republic of kosovo': 2,
#  '1945': 2,
#  'party wagon': 2,
#  "zac efron's pool party": 2,
#  'timeline': 2,
#  'bloodhounds of broadway': 2,
#  "pooh's heffalump halloween movie": 2,
#  '8 mile': 2,
#  'the duke steps out': 2,
#  'our huge adventure': 2,
#  'adventureland': 2,
#  'the shaggy dog': 2,
#  'vanuatu': 2,
#  'things we lost in the fire': 2,
#  'into the wild': 2,
#  'hemingway & gellhorn': 2,
#  'the molly maguires': 2,
#  '2002 bali bombings': 2,
#  'bophuthatswana': 2,
#  'striking poses': 2,
#  "the astronaut's wife": 2,
#  'the prophecy ii': 2,
#  'the secret life of bees': 2,
#  'a burning passion: the margaret mitchell story': 2,
#  'a very school gyrls holla-day': 2,
#  'lone wolf mcquade': 2,
#  'pan': 2,
#  'woman wanted': 2,
#  "my boss's daughter": 2,
#  'sing-along songs: the bare necessities': 2,
#  'on the fiddle': 2,
#  'freak': 2,
#  'an american crime': 2,
#  'ralph waite': 2,
#  '1973': 2,
#  'darkman': 2,
#  'kirk cameron': 2,
#  'crank: high voltage': 2,
#  'saudi arabia': 2,
#  'arabic alphabet': 2,
#  'the thirteenth year': 2,
#  'the shining hour': 2,
#  'the incredibles': 2,
#  'non-stop': 2,
#  'max havoc: curse of the dragon': 2,
#  'mulan': 2,
#  'my favorite martian': 2,
#  'obsessed': 2,
#  'me and orson welles': 2,
#  'house at the end of the street': 2,
#  'django unchained': 2,
#  'michael keaton': 2,
#  'homesteaders of paradise valley': 2,
#  'the circus': 2,
#  'on the edge of innocence': 2,
#  'la luna': 2,
#  'the wild': 2,
#  'marie antoinette': 2,
#  'the civil war': 2,
#  "blackbeard's ghost": 2,
#  'heathers': 2,
#  'staten island summer': 2,
#  'higglytown heroes: heroes on the move': 2,
#  'the scorpion king': 2,
#  'cannes: all access': 2,
#  'pretty ladies': 2,
#  'the kids are all right': 2,
#  'the hangover part ii': 2,
#  'dream machine': 2,
#  'gordy': 2,
#  'grand hotel': 2,
#  'spirit: stallion of the cimarron': 2,
#  'kill bill: the whole bloody affair': 2,
#  'the other man': 2,
#  'oceans of fire': 2,
#  "who's that girl": 2,
#  'stretch': 2,
#  'coach carter': 2,
#  'catholicism': 2,
#  "don't look down": 2,
#  'paid': 2,
#  'last stand at saber river': 2,
#  'zookeeper': 2,
#  'cry-baby': 2,
#  'man in the chair': 2,
#  'nikki, wild dog of the north': 2,
#  'mother goose parade': 2,
#  'eight legged freaks': 2,
#  'a guide to recognizing your saints': 2,
#  'struck by lightning': 2,
#  'star trek ii: the wrath of khan': 2,
#  'the name of the rose': 2,
#  'cocos (keeling) islands': 2,
#  'clean and sober': 2,
#  'criminal empire for dummies': 2,
#  'forfeit': 2,
#  'tiger warsaw': 2,
#  'dirty love': 2,
#  'benny & joon': 2,
#  'big buck bunny': 2,
#  'military conflict': 2,
#  "knocking on death's door": 2,
#  'the game of their lives': 2,
#  'starz inside: unforgettably evil': 2,
#  'the music man': 2,
#  'macau': 2,
#  'vanessa lachey': 2,
#  'henry winkler': 2,
#  'barry munday': 2,
#  'greenwich mean time zone': 2,
#  'deadline': 2,
#  'pashtun': 2,
#  'wanted': 2,
#  'billy elliot': 2,
#  'today we live': 2,
#  'the wedding singer': 2,
#  'moldova': 2,
#  'escobar: paradise lost': 2,
#  'boxcar bertha': 2,
#  'the answer man': 2,
#  '11:14': 2,
#  'how to train your dragon 2': 2,
#  'megiddo: the omega code 2': 2,
#  'license to drive': 2,
#  'luster': 2,
#  'bird on a wire': 2,
#  'lilo & stitch': 2,
#  'the little engine that could': 2,
#  'love and other impossible pursuits': 2,
#  'm.02wmyw7': 2,
#  'ye olde minstrels': 2,
#  'the wedding': 2,
#  'christine jm connors': 2,
#  'indonesian language': 2,
#  'tex': 2,
#  'the third rule': 2,
#  'hot tamale': 2,
#  'oceans': 2,
#  'living out loud': 2,
#  'anglo-frisian languages': 2,
#  'the blob': 2,
#  'winners of the wilderness': 2,
#  'toothless': 2,
#  'starstruck': 2,
#  'darfur regional authority': 2,
#  'mike and dave need wedding dates': 2,
#  'diary of the dead': 2,
#  'sundown: the vampire in retreat': 2,
#  'hinduism': 2,
#  'thunderball': 2,
#  'inside deep throat': 2,
#  'anger management': 2,
#  "madagascar 3: europe's most wanted": 2,
#  'havoc': 2,
#  'the chamber': 2,
#  'success is the best revenge': 2,
#  'falling sky': 2,
#  'the jacket': 2,
#  'soldier': 2,
#  'a far off place': 2,
#  'same kind of different as me': 2,
#  'matinee': 2,
#  'christmas caper': 2,
#  'little nicky': 2,
#  'the adventures of young indiana jones: daredevils of the desert': 2,
#  'oh, what a lovely tea party': 2,
#  'get a job': 2,
#  'buganda': 2,
#  'beautiful girls': 2,
#  'the immigrant': 2,
#  'defendor': 2,
#  'gibraltar': 2,
#  'aquamarine': 2,
#  'sweeney todd: the demon barber of fleet street': 2,
#  'rocket science': 2,
#  'abandon': 2,
#  'tar': 2,
#  'wales': 2,
#  'to die for': 2,
#  'q': 2,
#  'by way of helena': 2,
#  'estonia': 2,
#  "aussie & ted's great adventure": 2,
#  'bamboozled': 2,
#  'monsters, inc.': 2,
#  'the invasion': 2,
#  'the adventures of ichabod and mr. toad': 2,
#  'michael jackson: number ones': 2,
#  'the witches': 2,
#  'joey king': 2,
#  'the next man': 2,
#  'the eagle': 2,
#  'locke': 2,
#  'dawn of the planet of the apes': 2,
#  'beyond borders': 2,
#  'the fox and the hound': 2,
#  'live once, die twice': 2,
#  'brown sugar': 2,
#  'the vow': 2,
#  "it's a great feeling": 2,
#  'in the hive': 2,
#  'charles & ray eames: the architect and the painter': 2,
#  'territory of papua and new guinea': 2,
#  'outbreak': 2,
#  'blackout': 2,
#  'kisses in the dark': 2,
#  'old clothes': 2,
#  'that was then... this is now': 2,
#  'titan a.e.': 2,
#  'the whole wide world': 2,
#  'a crush on you': 2,
#  'canada pavilion': 2,
#  'tiger town': 2,
#  'the brothers grimm': 2,
#  'american splendor': 2,
#  'hatching pete': 2,
#  'jonas brothers: the concert experience': 2,
#  'kidnap': 2,
#  'the lord of the rings: the return of the king': 2,
#  'grand theft auto': 2,
#  'ali landry': 2,
#  'african american': 2,
#  'when your lover leaves': 2,
#  'palestinians': 2,
#  'empire of the sun': 2,
#  'the hunger games: mockingjay, part 1': 2,
#  'the players club': 2,
#  'curacao': 2,
#  'saw iv': 2,
#  'dream a little dream 2': 2,
#  'need': 2,
#  'step up 2: the streets': 2,
#  'follow me, boys!': 2,
#  'moulin rouge!': 2,
#  'full of it': 2,
#  'the innkeepers': 2,
#  'donnie brasco': 2,
#  'mardi gras: spring break': 2,
#  'the count': 2,
#  'finding neverland': 2,
#  'with this ring': 2,
#  'take the lead': 2,
#  'welcome home, roscoe jenkins': 2,
#  'garfield: the movie': 2,
#  'apache war smoke': 2,
#  '36 hours': 2,
#  'crazy, stupid, love.': 2,
#  'cowboy up': 2,
#  'king of california': 2,
#  'eritrea': 2,
#  'arizona dream': 2,
#  'trey songz': 2,
#  'jaws': 2,
#  'fantasia 2000': 2,
#  'the number 23': 2,
#  'knights of the roundtable: king arthur': 2,
#  'the little prince': 2,
#  'air bud: spikes back': 2,
#  'martial law': 2,
#  'fear and loathing in las vegas': 2,
#  'yoga hosers': 2,
#  'radio free albemuth': 2,
#  'leon: the professional': 2,
#  'ten minutes older: the trumpet': 2,
#  'flamingo road': 2,
#  'the a-team': 2,
#  'cheaper by the dozen': 2,
#  'paul blart: mall cop 2': 2,
#  'return to halloweentown': 2,
#  'the merry widow': 2,
#  'freaky deaky': 2,
#  'the ice follies of 1939': 2,
#  'weightless': 2,
#  'homeward bound: the incredible journey': 2,
#  'ruby bridges': 2,
#  'the people speak': 2,
#  'crime zone': 2,
#  'mallrats': 2,
#  'defiance': 2,
#  'kung fu panda holiday': 2,
#  'village of the giants': 2,
#  'just married': 2,
#  'secret admirer': 2,
#  'ethan frome': 2,
#  'the horse whisperer': 2,
#  'saw vi': 2,
#  'mickey, donald, goofy: the three musketeers': 2,
#  'shark city': 2,
#  'the spikes gang': 2,
#  'amazing stories: book one': 2,
#  "a dog's life": 2,
#  'm.03xdty5': 2,
#  'anatomy of a hate crime': 2,
#  'paddington': 2,
#  "and ya don't stop: hip hop's greatest videos, vol. 1": 2,
#  'the frightened city': 2,
#  'setup': 2,
#  'auto antics': 2,
#  'pt 109': 2,
#  'leroy & stitch': 2,
#  'the christmas star': 2,
#  'snowboard academy': 2,
#  'highlander ii: the quickening': 2,
#  'weapons': 2,
#  'the forger': 2,
#  'gia': 2,
#  'colorado pioneers': 2,
#  'a madea christmas': 2,
#  'antigua and barbuda': 2,
#  'alice in wonderland: through the looking glass': 2,
#  'george wallace': 2,
#  'love lies bleeding': 2,
#  'the shawshank redemption': 2,
#  'dance me to the end of love': 2,
#  'liars all': 2,
#  'cayman islands': 2,
#  'red dawn': 2,
#  'house of wax': 2,
#  'spider-man 3': 2,
#  'a certain sacrifice': 2,
#  'african development bank': 2,
#  'digging for fire': 2,
#  'the good guys and the bad guys': 2,
#  'the dilemma': 2,
#  'mokey': 2,
#  'bad night': 2,
#  'maladies': 2,
#  'all about us': 2,
#  'magnificent desolation: walking on the moon 3d': 2,
#  'autumn leaves': 2,
#  'why do fools fall in love': 2,
#  'balls to the wall': 2,
#  'the spongebob squarepants movie': 2,
#  'thunder run': 2,
#  'fun and fancy free': 2,
#  'batman v superman: dawn of justice': 2,
#  'insignificance': 2,
#  'frankie & alice': 2,
#  'matthew and son': 2,
#  'god said ha!': 2,
#  'the nanny diaries': 2,
#  '8 seconds': 2,
#  'newt': 2,
#  'the return of jafar': 2,
#  'triple trouble': 2,
#  'hoot': 2,
#  'an american rhapsody': 2,
#  'stephen baldwin': 2,
#  'jason mraz': 2,
#  "alfalfa's double": 2,
#  'drop dead gorgeous': 2,
#  'absolute evil': 2,
#  'his trysting place': 2,
#  'the skeptic': 2,
#  'herbie rides again': 2,
#  'reign of fire': 2,
#  'another cinderella story': 2,
#  'whatever happened to harold smith?': 2,
#  'before i go to sleep': 2,
#  'nancy pickard': 2,
#  'macbeth': 2,
#  'rudderless': 2,
#  'motocross kids': 2,
#  'street fighter: the legend of chun-li': 2,
#  'being michael madsen': 2,
#  'waking sleeping beauty': 2,
#  'aftershock': 2,
#  'fantastic mr. fox': 2,
#  'buck': 2,
#  'kissing a fool': 2,
#  'the road to el dorado': 2,
#  'law abiding citizen': 2,
#  'developing': 2,
#  'inventing the abbotts': 2,
#  'the hunting of the president': 2,
#  'idiots': 2,
#  'b*a*p*s': 2,
#  "billy lynn's long halftime walk": 2,
#  'the golden boys': 2,
#  'dolly parton': 2,
#  'brothers': 2,
#  'slaughter': 2,
#  'confessions of an action star': 2,
#  'batman forever': 2,
#  'teaching mrs. tingle': 2,
#  'serena': 2,
#  "don't say a word": 2,
#  'love & distrust': 2,
#  'tramp, tramp, tramp': 2,
#  'muppet treasure island': 2,
#  'stagecoach to denver': 2,
#  'the cookout': 2,
#  'the legend of bagger vance': 2,
#  'green zone': 2,
#  'nick lachey': 2,
#  'timor-leste': 2,
#  'race the sun': 2,
#  'the long riders': 2,
#  'the honeymooners': 2,
#  'battle of badung strait': 2,
#  'your highness': 2,
#  'the mod squad': 2,
#  'the martian': 2,
#  'life or something like it': 2,
#  'cut bank': 2,
#  'the majestic': 2,
#  'north atlantic treaty organization (nato)': 2,
#  'bulworth': 2,
#  'woman in gold': 2,
#  "beauty and the beast: belle's magical world": 2,
#  "pete's dragon": 2,
#  'warrior': 2,
#  'drive': 2,
#  'full disclosure': 2,
#  'biafra': 2,
#  'aaron dontez yates': 2,
#  'moscow': 2,
#  'g.i. joe: retaliation': 2,
#  'the hours': 2,
#  'jake lloyd': 2,
#  'welcome to japan, mr. bond': 2,
#  'cherry falls': 2,
#  'claire forlani': 2,
#  'the texas chainsaw massacre: the beginning': 2,
#  'ed wood': 2,
#  'from the rough': 2,
#  'school daze': 2,
#  'a night out': 2,
#  'mr. incredible and pals': 2,
#  'elsewhere': 2,
#  'dancing lady': 2,
#  'black rain': 2,
#  'american english': 2,
#  'freeze frame': 2,
#  'the big premiere': 2,
#  'wild horses': 2,
#  'a nightmare on elm street': 2,
#  'edison': 2,
#  'an american tail': 2,
#  'the talented mr. ripley': 2,
#  'obsession': 2,
#  'love & basketball': 2,
#  'at any cost': 2,
#  'heat': 2,
#  'the man who would be king': 2,
#  'how to train your dragon: gift of the night fury': 2,
#  'macon county jail': 2,
#  'black swan': 2,
#  'fast getaway': 2,
#  'seminole': 2,
#  'table 19': 2,
#  'kiss of a stranger': 2,
#  'war horse': 2,
#  'the wiz': 2,
#  'set it off': 2,
#  'flubber': 2,
#  'bond 25': 2,
#  'ben-hur': 2,
#  'journey into amazing caves': 2,
#  'blue-eyed butcher': 2,
#  'e.t. the extra-terrestrial': 2,
#  'the rink': 2,
#  'one week': 2,
#  'how to rob a bank': 2,
#  'savage': 2,
#  'possessed': 2,
#  "whispers: an elephant's tale": 2,
#  'barney frank': 2,
#  'behind the screen': 2,
#  'drive angry': 2,
#  'the big man': 2,
#  'twenty minutes of love': 2,
#  'air bud': 2,
#  'charlie and the chocolate factory': 2,
#  'toy story 3': 2,
#  'native americans in the united states': 2,
#  'the professor': 2,
#  'trolls': 2,
#  'priest': 2,
#  'namibia': 2,
#  'the face on the bar-room floor': 2,
#  'm.0519kxv': 2,
#  'red': 2,
#  'joe dirt 2: beautiful loser': 2,
#  'ryan phillippe': 2,
#  'chocolate city': 2,
#  'evita': 2,
#  'coast to coast': 2,
#  'sausage party': 2,
#  'good burger': 2,
#  'jersey girl': 2,
#  'hawaiian vacation': 2,
#  'twice upon a time': 2,
#  'hairspray 2: white lipstick': 2,
#  'the great mouse detective': 2,
#  'lucy punch': 2,
#  'time out for lessons': 2,
#  'saint lucia': 2,
#  'jewel of the sahara': 2,
#  'get him to the greek': 2,
#  'robin givens': 2,
#  'epic movie': 2,
#  'ladder 49': 2,
#  "a child's garden of poetry": 2,
#  'a prayer for the dying': 2,
#  "mickey mouse clubhouse: mickey's treat": 2,
#  'wanderlust': 2,
#  'melodies old and new': 2,
#  'federation of malaya': 2,
#  'jose mourinho': 2,
#  'destiny turns on the radio': 2,
#  'double dare': 2,
#  'welcome to hollywood': 2,
#  "you don't mess with the zohan": 2,
#  'laughing gas': 2,
#  'disappearing acts': 2,
#  'whatever it takes': 2,
#  'tommy boy': 2,
#  'the santa clause 2': 2,
#  'the long way home': 2,
#  'shakes the clown': 2,
#  'the richest cat in the world': 2,
#  'qwaqwa': 2,
#  'daybreak': 2,
#  'the whole truth': 2,
#  'lava': 2,
#  'nancy cartwright': 2,
#  'dough and dynamite': 2,
#  'the magnificent seven': 2,
#  'avatele': 2,
#  'cats & dogs': 2,
#  'karate cop': 2,
#  'a slipping-down life': 2,
#  'west point': 2,
#  'hell ride': 2,
#  'triangle': 2,
#  'otis': 2,
#  'abduction': 2,
#  'star wars episode iii: revenge of the sith': 2,
#  'remember me': 2,
#  'lovers & haters': 2,
#  'a tale of two cities': 2,
#  'a christmas carol': 2,
#  'puerto rico': 2,
#  'the thomas crown affair 2': 2,
#  'chasing amy': 2,
#  'trespass': 2,
#  'thor: the dark world': 2,
#  'sword of the valiant': 2,
#  'next of kin': 2,
#  'the expendables 2': 2,
#  'chris farley': 2,
#  'sudden fear': 2,
#  'roll of thunder, hear my cry': 2,
#  "darby o'gill and the little people": 2,
#  'a night to remember': 2,
#  'inspector gadget 2': 2,
#  'ticket out': 2,
#  'the source': 2,
#  "winter's bone": 2,
#  'chill factor': 2,
#  'our fathers': 2,
#  'margot at the wedding': 2,
#  'gray lady down': 2,
#  'satisfaction': 2,
#  'nina dobrev': 2,
#  'star': 2,
#  'northanger abbey': 2,
#  'frank and ollie': 2,
#  'the avengers': 2,
#  'kingdom of travancore': 2,
#  'annapolis': 2,
#  'cars': 2,
#  'caught in the rain': 2,
#  'yemen': 2,
#  'blended': 2,
#  'the lion king': 2,
#  'sandahl bergman': 2,
#  'requiem for murder': 2,
#  'american virgin': 2,
#  'forsaking all others': 2,
#  'sadie mckee': 2,
#  'shadows and lies': 2,
#  'unidentified flying oddball': 2,
#  'the phantom of the opera': 2,
#  'lara croft: tomb raider': 2,
#  'brunei': 2,
#  'hocus pocus': 2,
#  'the whole nine yards': 2,
#  'janet jackson': 2,
#  'some voices': 2,
#  'kazaam': 2,
#  "mickey's twice upon a christmas": 2,
#  'london': 2,
#  'beyond rangoon': 2,
#  'the chaplin revue': 2,
#  'stay': 2,
#  'little manhattan': 2,
#  'the original kings of comedy': 2,
#  "mabel's married life": 2,
#  'the house bunny': 2,
#  'twitches too': 2,
#  'the lucky one': 2,
#  'parkland': 2,
#  'miracle at sage creek': 2,
#  'city of joy': 2,
#  'one man band': 2,
#  'the ledge': 2,
#  'huckleberry finn': 2,
#  'that darn cat': 2,
#  'debra winger': 2,
#  'come back, miss pipps': 2,
#  'gone': 2,
#  "a marriage: georgia o'keeffe and alfred stieglitz": 2,
#  'a jitney elopement': 2,
#  'nowhere to run': 2,
#  'remember': 2,
#  'star trek nemesis': 2,
#  'inferno': 2,
#  'sin city': 2,
#  'harrison ford': 2,
#  'foxcatcher': 2,
#  'james dean': 2,
#  'lemonade mouth': 2,
#  'holiday in handcuffs': 2,
#  'fiona': 2,
#  'fast charlie... the moonbeam rider': 2,
#  'the love bug': 2,
#  'children of the corn': 2,
#  'the dressmaker': 2,
#  'afro-guyanese': 2,
#  'star wars episode ii: attack of the clones': 2,
#  'murder by decree': 2,
#  'the words': 2,
#  'still alice': 2,
#  'the dark tower': 2,
#  'if tomorrow comes': 2,
#  'some folks call it a sling blade': 2,
#  'over the hedge': 2,
#  'premium': 2,
#  'future zone': 2,
#  'five days one summer': 2,
#  'all hell broke loose': 2,
#  'windrider': 2,
#  'kung fu panda: secrets of the masters': 2,
#  'the spiral staircase': 2,
#  'a crack in the floor': 2,
#  "the gnomes' great adventure": 2,
#  'funny people': 2,
#  'sucker punch': 2,
#  'the wind and the lion': 2,
#  'the dirt bike kid': 2,
#  'equals': 2,
#  'blue in the face': 2,
#  'oregon trail scouts': 2,
#  'the pacifier': 2,
#  "nick & norah's infinite playlist": 2,
#  'harriet craig': 2,
#  'hotel chevalier': 2,
#  'interstellar': 2,
#  'hollywood takes a stand against planking': 2,
#  'young catherine': 2,
#  'camp': 2,
#  'dadnapped': 2,
#  'archangel': 2,
#  'the summer house': 2,
#  'the third person': 2,
#  'kingdom of heaven': 2,
#  'gone baby gone': 2,
#  'without evidence': 2,
#  'islam': 2,
#  'jack-jack attack': 2,
#  'dolphin tale 2': 2,
#  'disney princess enchanted tales: follow your dreams': 2,
#  'saw': 2,
#  'stop-loss': 2,
#  'zathura': 2,
#  'the sum of all fears': 2,
#  'recreation': 2,
#  'the one and only, genuine, original family band': 2,
#  'company town': 2,
#  'free zone': 2,
#  'meatballs part ii': 2,
#  '1942-03': 2,
#  ...}

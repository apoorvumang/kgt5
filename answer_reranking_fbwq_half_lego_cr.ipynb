# %%
import os
import pickle
from tqdm.notebook import tqdm
import networkx as nx

# %%
kg_name = 'fbwq_half_lego_cr'

# %%
def loadTriples(fname):
    f = open(fname)
    triples = []
    for line in f:
        if line.startswith('predict head:'):
            continue
        line = line.rstrip()
        line = line.replace('predict tail: ', '')
        head_rel, tail = line.split('\t')
        head_rel = head_rel.replace(' | ', '\t')
        head_rel = head_rel[:-2]
        head, rel = head_rel.split('\t')
        triples.append([head, rel, tail])
    return triples

def getEntities(triples):
    ents = set()
    for t in triples:
        ents.add(t[0])
        ents.add(t[2])
    return ents

def getHeadFromInputString(s):
    s = s.split('|')[0][:-1]
    s = s.replace('predict answer: ', '')
    return s

# %%
fname = os.path.join('data', kg_name, 'train_kgc_lines.txt')
train = loadTriples(fname)

# %%
entities = getEntities(train)
len(train), len(entities)
# Out:
# (376359, 153783)

# %%
G = nx.Graph()
G.add_nodes_from(entities)
for t in train:
    G.add_edge(t[0], t[2])

# %%
for e in entities:
    if 'was the 16th President' in e:
        print(e)
        break
# Out:
# Abraham Lincoln /ˈeɪbrəhæm ˈlɪŋkən/ was the 16th President of the United States, serving from March 1861 until his assassination in April 1865

# %%
import unicodedata

def normalize(s):
    return unicodedata.normalize('NFKC', s)

# %%
len(G)
# Out:
# 153783

# %%
fname = 'scores/scores_fbwq_half_lego_cr.pickle'
# fname = 'scores_500_base_trie|.pickle'
scores_data = pickle.load(open(fname, 'rb'))

# %%
from collections import defaultdict
predictions_scores_dicts = []
for string_arr, score_arr in tqdm(zip(scores_data['prediction_strings'], scores_data['scores'])):
    ps_pairs = [(p,s) for p,s in zip(string_arr, score_arr)]
    ps_pairs = list(set(ps_pairs)) # while sampling, duplicates are created
    # remove predictions that are not entities
    ps_dict_only_entities = defaultdict(list)
    for ps in ps_pairs:
#         if ps[0] in entity_strings_set:
        ps_dict_only_entities[ps[0]] = ps[1].item()
    predictions_scores_dicts.append(ps_dict_only_entities)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…

# %%
scores_data['input_strings'][47]
# Out:
# 'predict answer: Abraham Lincoln /ˈeɪbrəhæm ˈlɪŋkən/ was the 16th President of the United States, serving from March 1861 until his assassination in April 1865 | who was vp for NE'

# %%
import copy
from tqdm.notebook import tqdm
# do score reranking
predictions_filtered = copy.deepcopy(predictions_scores_dicts)
alpha = 0.5
count = 0
for i in tqdm(range(len(predictions_filtered))):
    input_string = scores_data['input_strings'][i]
    head = getHeadFromInputString(input_string)
    if head not in G:
        print(i, input_string)
        count += 1
        continue
    nbhood = set(G.neighbors(head))
    nbhood_2hop = nx.single_source_shortest_path_length(G, head, cutoff=2)
    for key in predictions_filtered[i].keys():
#         if key in nbhood:
#             predictions_filtered[i][key] += alpha
#             predictions_filtered[i][key] /= 10
        if key in nbhood_2hop:
            predictions_filtered[i][key] += alpha
#             predictions_filtered[i][key] /= 1.5
#     print(nbhood)
#     for j in range(len(predictions_filtered[i])):
#         print(predictions_filtered[j])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1639.0), HTML(value='')))
# 382 predict answer: UNK | who plays blaine in NE
# 522 predict answer: UNK | who did NE play for before arsenal
# 683 predict answer: UNK | who plays NE
# 907 predict answer: UNK | what does NE stand for
# 1130 predict answer: UNK | when was the last time the NE went to the stanley cup

# %%
count
# Out:
# 5

# %%
predictions_filtered[0]
# Out:
# defaultdict(list,
#             {'Spanish, also called Castilian, is a Romance language that originated in the Castile region of Spain': -0.23698104918003082,
#              'Jamaican Patois, known locally as Patois and called Jamaican Creole by linguists, is an English-based creole language with West African influences spoken primarily in Jamaica': 0.45556076243519783,
#              'English is a West Germanic language that was first spoken in early medieval England and is now a global lingua franca': -0.18310873210430145,
#              'Jamaican English which includes Jamaican Standard English is a variety of English spoken in Jamaica': 0.4905648035928607})

# %%
num_correct = 0
ans_to_improve = []
for i in range(len(predictions_filtered)):
    target = scores_data['target_strings'][i]
    ps_dict = predictions_filtered[i]
    ps_sorted = sorted(ps_dict.items(), key=lambda item: -item[1])
    if len(ps_dict) == 0:
        preds = []
        best_pred = "NOT FOUND"
    else:
        preds = [x[0] for x in ps_sorted]
        best_pred = preds[0]
    if best_pred in target:
        num_correct += 1
    if best_pred not in target and len(set(preds).intersection(set(target))) > 0:
#         print(i)
        ans_to_improve.append(i)
        pass
print(num_correct/len(predictions_filtered))
# Out:
# 0.4636973764490543

# %%
id = ans_to_improve[4]
print(scores_data['input_strings'][id])
print(scores_data['target_strings'][id])
for k,v in predictions_filtered[id].items():
    print(k, predictions_scores_dicts[id][k])
print()
for k,v in predictions_filtered[id].items():
    print(k, v)
# Out:
# predict answer: Brentwood is a city and an affluent suburb of Nashville located in Williamson County, Tennessee | what county is NE in
# ['Williamson County is a county in the U', 'Williamson County is a county in the U']
# Tennessee is a U -0.003469762159511447
# Alabama is a state located in the southeastern region of the United States -0.3175763785839081
# Arkansas is a state located in the Southern region of the United States -0.33980780839920044
# Williamson County is a county in the U -0.5109785199165344
#
# Tennessee is a U 0.49653023784048855
# Alabama is a state located in the southeastern region of the United States -0.3175763785839081
# Arkansas is a state located in the Southern region of the United States -0.33980780839920044
# Williamson County is a county in the U -0.010978519916534424

# %%
print(scores_data['input_strings'][id])
print(scores_data['target_strings'][id])
for k,v in predictions_scores_dicts[id].items():
    print(k, v)
# Out:
# predict answer: Brentwood is a city and an affluent suburb of Nashville located in Williamson County, Tennessee | what county is NE in
# ['Williamson County is a county in the U', 'Williamson County is a county in the U']
# Tennessee is a U -0.003469762159511447
# Alabama is a state located in the southeastern region of the United States -0.3175763785839081
# Arkansas is a state located in the Southern region of the United States -0.33980780839920044
# Williamson County is a county in the U -0.5109785199165344

# %%
head = getHeadFromInputString(scores_data['input_strings'][id])
# set(G.neighbors(head))

# %%
nx.single_source_shortest_path_length(G, head, cutoff=2)
# Out:
# {'Brentwood is a city and an affluent suburb of Nashville located in Williamson County, Tennessee': 0,
#  '16457': 1,
#  '22090': 1,
#  '18880': 1,
#  'Williamson County is a county in the U': 1,
#  '17968': 1,
#  'Tennessee is a U': 1,
#  'City/town/village refers to all named inhabited places at the most locally recognized level, but above the level of neighborhood': 1,
#  'Novopavlovsk is a town and the administrative center of Kirovsky District in Stavropol Krai, Russia, located on the left bank of the Kura River': 2,
#  'Saint-Zotique is a Quebec municipality located within the Vaudreuil-Soulanges Regional County Municipality in the Montérégie region located about 45 minutes west of Montreal': 2,
#  'Pinnacle Peak Village': 2,
#  'Bay Bulls is a small fishing community in the province of Newfoundland and Labrador, Canada': 2,
#  'Thorncliffe is a residential neighbourhood in the north-east quadrant of Calgary, Alberta': 2,
#  'Nakashibetsu is a town located in Shibetsu District, Nemuro Subprefecture, Hokkaido, Japan': 2,
#  'Atlanta Township is located in Logan County, Illinois': 2,
#  'Barrax is a municipality in the province of Albacete': 2,
#  'Olivella is a municipality in Catalonia, in the province of Barcelona, Spain': 2,
#  'Foz is a town and municipality in A Mariña country in the Galician province of Lugo': 2,
#  'Berthierville is a Canadian town located between Montreal and Trois-Rivières on the north shore of the Saint Lawrence River in the province of Quebec': 2,
#  'Alto Township is one of twenty-two townships in Lee County, Illinois, USA': 2,
#  'Tyukalinsk is a town in Omsk Oblast, Russia, located 60 kilometers northeast of the Nazyvayevsk railway station on the Trans-Siberian Railway and 120 kilometers northwest': 2,
#  'Nuño Gómez is a municipality located in the province of Toledo, Castile-La Mancha, Spain': 2,
#  'Lipetsk is a city and the administrative center of Lipetsk Oblast, Russia, located on the banks of the Voronezh River in the Don basin, 438': 2,
#  'Wedges Corner': 2,
#  'Atwood Park Estates': 2,
#  'Pebble Beach': 2,
#  'Nishiazai was a town located in Ika District, Shiga Prefecture, Japan': 2,
#  'Konodimini is a village and rural commune in the Cercle of Ségou in the Ségou Region of southern-central Mali': 2,
#  'Suntree': 2,
#  'Roots': 2,
#  'Teulon is a town located approximately 59 kilometers north of Winnipeg, Manitoba, Canada, on Provincial Truck Highway 7': 2,
#  'San Cristóbal de Boedo is a municipality located in the province of Palencia, Castile and León, Spain': 2,
#  'Awara is a city located in Fukui Prefecture, Japan': 2,
#  'Watertown': 2,
#  'King Acres': 2,
#  'Ōita is the capital city of Ōita Prefecture, located on the island of Kyushu, Japan': 2,
#  'Diamond Village is a small farming village on the windward side of St': 2,
#  'Guatemala City, locally known as Guatemala or Guate, is the capital and largest city of the Republic of Guatemala, and the most populous in Central': 2,
#  'Sacramento is a city in the northern Mexican state of Coahuila': 2,
#  'Blackhawk is an unincorporated community in Carroll County, Illinois, United States': 2,
#  'Mimata is a town located in Kitamorokata District, Miyazaki Prefecture, Japan': 2,
#  'Ndande Arrondissement is an arrondissement of the Kébémer Department in the Louga Region of Senegal': 2,
#  'Fafaya is a town and sub-prefecture in the Koubia Prefecture in the Labé Region of northern Guinea': 2,
#  'Diaramana is a small town and commune in the Cercle of Bla in the Ségou Region of southern-central Mali': 2,
#  'Winnipegosis was a village in Manitoba, Canada that had a population of 647 in 2011': 2,
#  'Kinkō is a town located in Kimotsuki District, Kagoshima Prefecture, Japan': 2,
#  'Edam is a village in Saskatchewan, Canada': 2,
#  'Okhansk is a town and the administrative center of Okhansky District in Perm Krai, Russia, located on the right bank of the Kama River, 119': 2,
#  'Saltangará is a village in the Faroe Islands, on the island of Eysturoy': 2,
#  'Los Hinojosos is a municipality in located in the province of Cuenca, Castile-La Mancha, Spain': 2,
#  'Lakeview is an unincorporated community in Beaverhead County, Montana, United States': 2,
#  'Nasu is a town located in Nasu District, Tochigi Prefecture, Japan': 2,
#  'Forest Acres Mobile Home Park': 2,
#  'Plateau is a town and commune in Ivory Coast': 2,
#  "Foto-Kouamékro is a town and commune in Côte d'Ivoire": 2,
#  'Izu is a city located in central Izu Peninsula in Shizuoka Prefecture, Japan': 2,
#  'Mountain Shadows Estates': 2,
#  'Shippagan is a Canadian town in Gloucester County, New Brunswick': 2,
#  "N'Tjikouna is a village and rural commune in the Cercle of Sikasso in the Sikasso Region of southern Mali": 2,
#  'Séféto is a small town and principal settlement of the commune of Séféto Ouest in the Cercle of Kita in the Kayes Region of south-western': 2,
#  'Vaudreuil-Dorion is an off-island suburb of Montreal, in southwestern Quebec': 2,
#  'Irkutsk is a city and the administrative center of Irkutsk Oblast, Russia, and one of the largest cities in Siberia': 2,
#  'Woodland Junction': 2,
#  'Toya is a commune in the Cercle of Yélimané in the Kayes Region of south-western Mali': 2,
#  'Sturgis is a town of 620 people in east central Saskatchewan, Canada': 2,
#  'Mikun is a town in Ust-Vymsky District of the Komi Republic, Russia, located 96 kilometers north of Syktyvkar': 2,
#  'Diamniadio Arrondissement is an arrondissement of the Rufisque Department in the Dakar Region of Senegal': 2,
#  'Casas de Monleón is small village or hamlet in the southeast corner of the province of Salamanca, Spain': 2,
#  "Koumbala is a town and commune in the Ferkessédougou Department, in the Savanes Region of northern Côte d'Ivoire": 2,
#  'Awashimaura is a village located on Awashima Island, in Iwafune District, Niigata Prefecture, Japan': 2,
#  'Mirador Norte is a Sector in the city of Santo Domingo in the Distrito Nacional of the Dominican Republic': 2,
#  'Springhill Park': 2,
#  'Sheridan is a town in Madison County, Montana, United States named after the Civil War general Philip Sheridan': 2,
#  'Amherst': 2,
#  'Sagalé is a town and sub-prefecture in the Lélouma Prefecture in the Labé Region of northern-central Guinea': 2,
#  'Kawashima was a town located in Oe District, Tokushima Prefecture, Japan': 2,
#  'Evanston is a residential neighbourhood in the northwest quadrant of Calgary, Alberta': 2,
#  'Torrecilla de Alcañiz is a municipality located in the province of Teruel, Aragon, Spain': 2,
#  'Lost Creek': 2,
#  'Camden': 2,
#  'Pineda Trasmonte is a municipality and town located in the province of Burgos, Castile and León, Spain': 2,
#  'Nuñomoral is the head village of a municipality of the same name located in the center of the comarca of Las Hurdes, province of Cáceres,': 2,
#  'Chkhorotsqu is a townlet in western Georgia, located in the region of Samegrelo-Zemo Svaneti and functioning as the administrative center of the homonymous district': 2,
#  'Garnish, a town located on the west coast of the Burin Peninsula, was well known for its lumbering and now for its lobstering operations': 2,
#  'Mayakovskoye, previously known in German as Nemmersdorf, is a rural locality in Gusevsky District of Kaliningrad Oblast, Russia, located on the banks of the Angrapa': 2,
#  'Starocherkasskaya, formerly Cherkassk, is a rural locality in Aksaysky District of Rostov Oblast, Russia, with origins dating from the late 16th century': 2,
#  "Assalé-Kouassikro is a town and commune in Côte d'Ivoire": 2,
#  'Charlotte': 2,
#  'Hughes Brook is a town in the Canadian province of Newfoundland and Labrador': 2,
#  'Algorta is a locality within the municipality of Getxo, in the province of Biscay, Basque Country, Spain': 2,
#  'Harrisonville is an unincorporated community in the historic Harrisonville Precinct of Monroe County, Illinois': 2,
#  'Gorebridge is a post town and former mining village in Midlothian, Scotland': 2,
#  'Salair is a town administratively subordinated to Guryevsk Town Under Oblast Jurisdiction in Kemerovo Oblast, Russia, located 210 kilometers south of Kemerovo, the administrative center': 2,
#  'Moriles is a town in the province of Córdoba': 2,
#  'Nadachi was a town located in Nishikubiki District, Niigata Prefecture, Japan': 2,
#  'Washoe is a settlement in Carbon County, Montana, at the foot of the Beartooth Mountains': 2,
#  'Kollet is a town and sub-prefecture in the Tougué Prefecture in the Labé Region of northern-central Guinea': 2,
#  'Country Cousins Mobile Mecca': 2,
#  'Valdepeñas de la Sierra is a municipality located in the province of Guadalajara, Castile-La Mancha, Spain': 2,
#  'Asbury Township is one of ten townships in Gallatin County, Illinois, USA': 2,
#  'Yawata was a town located in Akumi District, Yamagata Prefecture, Japan': 2,
#  'Tonopah /ˈtoʊnɵpɑː/ is a census-designated place in western Maricopa County, Arizona, United States, approximately 50 miles west of downtown Phoenix off Interstate 10': 2,
#  "Koréahinou is a town and commune in the Soubré Department, Côte d'Ivoire": 2,
#  'Uclés is a municipality located in the province of Cuenca, Castile-La Mancha, Spain': 2,
#  'McCloud': 2,
#  "Brihiri is a town and commune in Côte d'Ivoire": 2,
#  'Navàs is a town and municipality in the province of Barcelona and autonomous community of Catalonia, Spain': 2,
#  'Ryūō was a town located in Nakakoma District, Yamanashi Prefecture, Japan': 2,
#  'Tahta, Sohag is a city in the Sohag Governorate of Upper Egypt': 2,
#  'Volborg is an unincorporated community in Custer County, Montana, United States': 2,
#  'Yamanashi is a city located in Yamanashi Prefecture, Japan': 2,
#  'Hokota is a city located in Ibaraki Prefecture, Japan': 2,
#  'Tortuera is a municipality located in the province of Guadalajara, Castile-La Mancha, Spain': 2,
#  'Dalnegorsk is a town in Primorsky Krai, Russia': 2,
#  'Obama was a town located in Minamitakaki District, Nagasaki Prefecture, Japan': 2,
#  'Myshkin is a town and the administrative center of Myshkinsky District in Yaroslavl Oblast, Russia, located on the steep left bank of the Volga': 2,
#  'Hawkwood is a residential neighbourhood in the north-west quadrant of Calgary, Alberta': 2,
#  'Bond': 2,
#  'Tolo, Guinea is a town and sub-prefecture in the Mamou Prefecture in the Mamou Region of Guinea': 2,
#  'Takasato was a village in Yama District, Fukushima Prefecture, Japan': 2,
#  'Sandy Ground is a village and one of the fourteen Districts of Anguilla, and its main port': 2,
#  'Eddy': 2,
#  'Hayakita was a town located in Yūfutsu District, Iburi Subprefecture, Hokkaido, Japan': 2,
#  'Øravíkarlíð or Líðin is a village on the island Suðuroy, Faroe Islands': 2,
#  "N'Gara is a village and rural commune in the Cercle of Ségou in the Ségou Region of southern-central Mali": 2,
#  'Tikhvin is a town and the administrative center of Tikhvinsky District in Leningrad Oblast, Russia, located on both banks of the Tikhvinka River in the': 2,
#  'Belle-Vue Court': 2,
#  'Corette': 2,
#  'Logduz is a rural locality in Babushkinsky District of Vologda Oblast, Russia, located on the Sharzhenga River, 370 kilometers from Vologda, the administrative center of': 2,
#  'Nagahama was a town located in Kita District, Ehime Prefecture, Japan': 2,
#  'Alarilla is a municipality located in the province of Guadalajara, Castile-La Mancha, Spain': 2,
#  'New City is an unincorporated community in Cotton Hill Township, Sangamon County, Illinois, United States, in the rural center of the state': 2,
#  'Ardatov is a town and the administrative center of Ardatovsky District of the Republic of Mordovia, Russia, located on the Alatyr River 114 kilometers northeast': 2,
#  'Ohrdruf is a small town in the district of Gotha in the German state of Thuringia': 2,
#  'Hikata was a town located in Katori District, Chiba Prefecture, Japan': 2,
#  'Peaks and Pines Park': 2,
#  'Buckeye': 2,
#  'Fuheis is a town in the Jordanian governorate of Balqa, just 20 kilometers northwest of Amman': 2,
#  'Rubena is a municipality and town located in the province of Burgos, Castile and León, Spain': 2,
#  'Mountain View': 2,
#  'Rock Grove is an unincorporated community in Stephenson County, Illinois, located 6': 2,
#  'South Pole': 2,
#  'Minto is a Canadian village straddling the border of Sunbury County and Queens County, New Brunswick': 2,
#  'Ottawa is a city located at the confluence of the navigable Illinois River and Fox River in LaSalle County, Illinois, USA': 2,
#  'Bulgakovo is a rural locality in Ufimsky District of the Republic of Bashkortostan, Russia, located 42 kilometers north of Ufa, the capital of the republic': 2,
#  'Gravelbourg is a small multicultural town in south central Saskatchewan, Canada': 2,
#  'Ropsha is a settlement in Lomonosovsky District of Leningrad Oblast, Russia, situated about 20 kilometres south of Peterhof and 49 kilometres south-west of central Saint': 2,
#  'Grand Falls is a Canadian town located in Victoria County, New Brunswick, with a population of 5,706 at the 2011 census': 2,
#  'Bay Roberts is located on the north shore of Conception Bay on the Bay de Verde Peninsula in the province of Newfoundland and Labrador, Canada': 2,
#  'Honeymoon Row': 2,
#  "Casas de Don Pedro, meaning 'Lord Peter ́s houses', is a municipality located in the province of Badajoz, Extremadura, Spain": 2,
#  'Colpton is a Canadian rural community in Lunenburg County, Nova Scotia': 2,
#  'Izalzu – Itzaltzu is a town and municipality located in the province and autonomous community of Navarre, northern Spain': 2,
#  'Albalat dels Tarongers is a municipality in the comarca of Camp de Morvedre in the Valencian Community, Spain': 2,
#  'Gamètì, officially the Tlicho Community Government of Gameti is a community in the North Slave Region of the Northwest Territories, Canada': 2,
#  'Trego is an unincorporated community in Lincoln County, Montana, United States': 2,
#  "Pinhou is a town and commune in Côte d'Ivoire": 2,
#  'Topas is a municipality located in the province of Salamanca, Castile and León, Spain': 2,
#  'Donggang is a city in the southeast of Liaoning Province in Northeast China': 2,
#  'Oliva de Plasencia is a municipality located in the province of Cáceres, Extremadura, Spain': 2,
#  'Mt. Olive Township is located in Macoupin County, Illinois, USA': 2,
#  'Bonfield': 2,
#  'Idko, also spelt Edkou is a town in Beheria, Egypt, Egypt': 2,
#  'Los Cortijos is a municipality in Ciudad Real, Castile-La Mancha, Spain': 2,
#  'Teúl de González Ortega Municipality is a town and municipality located in the south of the Mexican state of Zacatecas, between the state capital of': 2,
#  'Kira Ouest is a rural commune in the Cercle of Kita in the Kayes Region of south-western Mali': 2,
#  'Finnicum Mobile Home Park': 2,
#  'Sangrave is a town and commune in the Brakna Region of southern Mauritania': 2,
#  'Dilly is a village and rural commune in the Cercle of Nara in the Koulikoro Region of south-western Mali': 2,
#  "Bla, population 15,000, is a small town in Mali's Ségou Region, located 85 kilometers south of Ségou along Mali's main highway": 2,
#  'Meriwether': 2,
#  'Diarra, Mali is a small town and commune in the Cercle of Nioro du Sahel in the Kayes Region of south-western Mali': 2,
#  'Choi Uk Tsuen or Tsoi Uk Tsuen is a village in Yuen Long Kau Hui, in the Yuen Long District of Hong Kong, China': 2,
#  'Union Hill': 2,
#  'Honjō is a city in Saitama Prefecture, Japan': 2,
#  'Como is a census-designated place in Whiteside County, Illinois, United States': 2,
#  'Cedar Point is a village in LaSalle County, Illinois, United States': 2,
#  'Bridlewoods': 2,
#  'Woodbine': 2,
#  "Fronan is a town and commune in Côte d'Ivoire": 2,
#  'Abra is a town and commune in Ivory Coast': 2,
#  "Niorouhio is a town and commune in the Guéyo Department, Côte d'Ivoire": 2,
#  'Mount Vernon known as \\The King City\\ is a city in and the county seat of Jefferson County, Illinois, United States': 2,
#  'Willemstad is the capital city of Curaçao, an island in the southern Caribbean Sea that forms a constituent country of the Kingdom of the Netherlands': 2,
#  'Hill Top is an unincorporated community in Menard County, Illinois, United States': 2,
#  '2177000': 2,
#  'Clasoil': 2,
#  'Santa Pola is a coastal town located in the comarca of Baix Vinalopó in the Valencian Community, Spain, by the Mediterranean Sea': 2,
#  "Blapleu is a town and commune in the Biankouma Department, Côte d'Ivoire": 2,
#  'Cowden is a village in Shelby County, Illinois, United States': 2,
#  '3673000': 2,
#  'Mito was a town located in Mino District, Shimane Prefecture, Japan': 2,
#  'Yasuzuka was a town located in Higashikubiki District, Niigata Prefecture, Japan': 2,
#  'Alfoz de Bricia is a municipality located in the province of Burgos, Castile and León, Spain': 2,
#  'Plymouth was the capital of the island of Montserrat, an overseas territory of the United Kingdom located in the Leeward Island chain of the Lesser': 2,
#  'Kamennogorsk, known under the Finnish name of Antrea before 1948, is a town in Vyborgsky District of Leningrad Oblast, Russia, located on the Karelian Isthmus': 2,
#  'Royal Heights': 2,
#  'Lolo Hot Springs is an unincorporated community in Missoula County, Montana, United States': 2,
#  'Azuma was a village located in Nitta District, Gunma Prefecture, Japan': 2,
#  'Cookes Subdivision': 2,
#  'Hvítanes is a village in the Faroe Islands, noted for its beauty': 2,
#  'Yubara was a town located in Maniwa District, Okayama Prefecture, Japan': 2,
#  'Thiaroye is the name of a historic town in Sénégal, situated in the suburbs of Dakar, on the southeast coast of the Cap-Vert peninsula, between': 2,
#  'The town of Ribadavia is located in the southwest of the province of Ourense, Autonomous Community of Galicia, Spain': 2,
#  'Cheeseekau, better known as Matthew, was a war chief of the Kispoko division of the Shawnee Nation': 2,
#  'Marañón is a town and municipality located in the province and autonomous community of Navarre, northern Spain': 2,
#  'Moclín is a municipality in the province of Granada, Spain': 2,
#  'Paradise Grove Family Park': 2,
#  "Afotobo is a town and commune in the department of Béoumi in Côte d'Ivoire": 2,
#  'El Mina is a suburb of Nouakchott and urban commune in western Mauritania': 2,
#  'Ōtawara is a city located in eastern Tochigi Prefecture, Japan; which is in the northern part of the Kantō region north of Tokyo': 2,
#  'Paradise Grove Trailer Park': 2,
#  "Dialakoro, Côte d'Ivoire is a town and commune in Côte d'Ivoire": 2,
#  'Arfamoussaya is a town and sub-prefecture in the Dabola Prefecture in the Faranah Region of western Guinea': 2,
#  'Rocky Harbour is a town located on the western edge of Newfoundland, near the entrance to Bonne Bay': 2,
#  'Taiki is a town located in Hiroo District, Tokachi Subprefecture, Hokkaido, Japan': 2,
#  'Wellsville is a city in Montgomery County, Missouri, United States': 2,
#  'Herrick Township is located in Shelby County, Illinois': 2,
#  'Hampton Court is a small district on the eastern tip of Saint Thomas, the most easterly parish on the Island of Jamaica': 2,
#  'Gano': 2,
#  'Herrick is a village in Shelby County, Illinois, United States': 2,
#  'Kinkaid Township is one of sixteen townships in Jackson County, Illinois, USA': 2,
#  'Bridlewood is a residential neighbourhood in the south-west quadrant of Calgary, Alberta': 2,
#  'Bridger is a town in Carbon County, Montana, United States': 2,
#  "Béréni Dialla is a town and commune in Côte d'Ivoire": 2,
#  'Yoshioka is a town located in Kitagunma District of central Gunma Prefecture in the northern Kantō region of Japan': 2,
#  'Kunohe is a villaga located in Kunohe District, Iwate, Japan': 2,
#  "Guékpé is a town and commune in Côte d'Ivoire": 2,
#  'Maxville': 2,
#  "Bonikro is a town and commune in the Toumodi Department, Côte d'Ivoire": 2,
#  "Anstey's Cove is a hamlet in the Twillingate district, near Little Bay Islands": 2,
#  'Badr City is a suburb in north eastern Cairo Governorate, Egypt': 2,
#  'Oktyabrsky is a city in the Republic of Bashkortostan, Russia, located on the Ik River': 2,
#  "Kongoussi is a city located in Bam Province in central Burkina Faso, one of the world's poorest countries": 2,
#  'Nora Township is one of twenty-three townships in Jo Daviess County, Illinois, USA': 2,
#  'Cloverdale': 2,
#  'Bitterroot Pines': 2,
#  'Savant Lake is an unincorporated place and community in Unorganized Thunder Bay District in northwestern Ontario, Canada': 2,
#  'Rubielos de la Cérida is a municipality located in the province of Teruel, Aragon, Spain': 2,
#  'Inasa was a town located in Inasa District, Shizuoka Prefecture, Japan': 2,
#  'Harue was a town located in Sakai District, Fukui Prefecture, Japan': 2,
#  'Danley': 2,
#  'Geyser is a small census-designated place in central Judith Basin County, Montana, United States, approximately 50 miles from Great Falls along US-87': 2,
#  'Massacre is a town in Saint Paul Parish, Dominica, with about 1,200 inhabitants': 2,
#  'Carabaña is a small municipality in the autonomous community of Madrid in central Spain': 2,
#  'Butucu is a village on the island of Aruba, located towards the southernmost point of the island': 2,
#  'Hayato was a town located in Aira District, Kagoshima Prefecture, Japan': 2,
#  'Sandusky is an unincorporated community in Alexander County, Illinois, United States': 2,
#  'Blackberry Township is located in Kane County, Illinois': 2,
#  'Belle Prairie Township is located in Livingston County, Illinois in the United States': 2,
#  'Urús is a village in the province of Girona and autonomous community of Catalonia, Spain': 2,
#  'Shawnee Township is one of ten townships in Gallatin County, Illinois, USA': 2,
#  'Delices is a small village in the Caribbean nation of Dominica': 2,
#  "Kossou is a town and commune in the Yamoussoukro Department, Côte d'Ivoire": 2,
#  'Crete Township is located in Will County, Illinois': 2,
#  'Omutninsk is a town and the administrative center of Omutninsky District in Kirov Oblast, Russia': 2,
#  'Spassk-Dalny, sometimes called simply Spassk, is a town in Primorsky Krai, Russia, situated on the Prikhankayskaya Flatland on the coast of Khanka Lake': 2,
#  'Kennedy Town is at the western end of Sai Wan on Hong Kong Island in Hong Kong': 2,
#  'Novaya Ladoga is a town in Volkhovsky District of Leningrad Oblast, Russia, located at the point where the Volkhov River flows into Lake Ladoga, 140': 2,
#  'Claremont Place': 2,
#  'Capitol Oaks': 2,
#  'Kolyvan is a rural locality in Kuryinsky District of Altai Krai, Russia, located on the slopes of the Kolyvan Range': 2,
#  'Northeast Annexation Trailer Court': 2,
#  'Candela is a city in the central region of the northern Mexican state of Coahuila': 2,
#  "Bonguéra is a town and commune in Côte d'Ivoire": 2,
#  'Kéméné Tambo is a commune in the Cercle of Kayes in the Kayes Region of south-western Mali': 2,
#  'Mollet de Peralada is a municipality in the comarca of Alt Empordà, Girona, Catalonia, Spain': 2,
#  'Hoosier Township is one of twelve townships in Clay County, Illinois, USA': 2,
#  'Shimoji was a town located in Miyako District, Okinawa Prefecture, Japan': 2,
#  "Bazré is a town and commune in Côte d'Ivoire": 2,
#  'Aguaruto is a small town just west of the larger city of Culiacán, Sinaloa, Mexico': 2,
#  'Casalarreina is a town located in the province of La Rioja, Spain': 2,
#  'Saint Martins is a village in Saint Philip Parish in Barbados': 2,
#  'Malé or Sori Malé or Mal is a town and commune in the Brakna Region of southern Mauritania on the border with Senegal': 2,
#  'Sissin is a village in the Zimtenga Department of Bam Province in northern-central Burkina Faso': 2,
#  'Peremyshl is a rural locality and the administrative center of Peremyshlsky District of Kaluga Oblast, Russia': 2,
#  'Willard is an unincorporated community in Fallon County, Montana, United States': 2,
#  'Arandilla del Arroyo is a municipality in Cuenca, Castile-La Mancha, Spain': 2,
#  'Obama is a city in Fukui Prefecture, Japan': 2,
#  'Uchinada is a small beach town located in Kahoku District, Ishikawa Prefecture, Japan': 2,
#  'Farrington is an unincorporated community in Clark County, Illinois, United States': 2,
#  'Unionville is an unincorporated community in Union Grove Township, Whiteside County, Illinois, United States': 2,
#  'Wildebrook On The Green': 2,
#  'Grand Pass': 2,
#  'Wine Hill is an unincorporated community in Randolph County, Illinois, United States': 2,
#  'Tucson is a city in and the county seat of Pima County, Arizona, United States, and home to the University of Arizona': 2,
#  'Kingsbury Colony': 2,
#  'Urayasu is a city located in the far western corner of northern Chiba Prefecture, Japan': 2,
#  'Karachev is an ancient town and the administrative center of Karachevsky District in Bryansk Oblast, Russia': 2,
#  'Kem is a historic town and the administrative center of Kemsky District of the Republic of Karelia, Russia, located on the shores of the White': 2,
#  'El Chupadero is a town in the municipality of Santa Rita, Chalatenango, El Salvador': 2,
#  'Fimela Arrondissement is an arrondissement of the Fatick Department in the Fatick Region of Senegal': 2,
#  'Midges Court': 2,
#  'Peromingo is a municipality located in the province of Salamanca, Castile and León, Spain': 2,
#  'Châteauguay is an off-island suburb of Montreal, in southwestern Quebec, located both on the Chateauguay River and Lac St-Louis, which is a section of the': 2,
#  'Sunburst Homes': 2,
#  "L'Alqueria d'Asnar is a municipality in the comarca of Comtat in the Valencian Community, Spain": 2,
#  'Airport Business Area is an industrial park located in the North Industrial SDA Suburban Development Area of Saskatoon, Saskatchewan': 2,
#  'Coria del Río is a small town near Seville, on the shores of Guadalquivir river': 2,
#  'Jamapa is a city in the Mexican state of Veracruz': 2,
#  'Azgueilem Tiyab is a town and commune in the Gorgol Region of southern Mauritania': 2,
#  'Mont-Organisé is a commune in the Ouanaminthe Arrondissement, in the Nord-Est Department of Haiti': 2,
#  'Nizhnekolymsk is a rural locality in Pokhodsky Rural Okrug of Nizhnekolymsky District in the Sakha Republic, Russia, located within the Arctic Circle near the East': 2,
#  'Deer Park': 2,
#  'Chernyshevskoye is a settlement in Nesterovsky District in the eastern part of Kaliningrad Oblast, Russia, on the border with Lithuania': 2,
#  'Belinsky is a town and the administrative center of Belinsky District in Penza Oblast, Russia, located at the confluence of the Bolshoy and Maly Chembar': 2,
#  'Brandon': 2,
#  'Carberry is the largest town in the Rural Municipality of North Cypress in southwestern Manitoba, Canada': 2,
#  'Jackson Park Terrace': 2,
#  'Jorba is a municipality in the comarca of the Anoia in Catalonia, Spain': 2,
#  'Orland Hills is a village in Cook County, Illinois, United States': 2,
#  'Horokanai is a town located in Uryū District, Kamikawa Subprefecture, Hokkaido, Japan': 2,
#  'Bikin is a town in Khabarovsk Krai, Russia, located on the Bikin River 230 kilometers southwest of Khabarovsk': 2,
#  'Marlen Subdivision': 2,
#  'Breiðdalsvík is a young fishing town in Iceland': 2,
#  'Edgington Township is located in Rock Island County, Illinois': 2,
#  'Woodland Acres': 2,
#  'Valle de Santa Ana is a municipality located in the province of Badajoz, Extremadura, Spain': 2,
#  'Pedrosa del Páramo is a municipality located in the province of Burgos, Castile and León, Spain': 2,
#  'Wakakusa is an area located within the city of Minami-Alps in Yamanashi Prefecture, Japan': 2,
#  'Deifontes is a municipality located in the province of Granada, Spain': 2,
#  'Sankarani is a rural commune in the Cercle of Yanfolila in the Sikasso Region of southern Mali': 2,
#  'Far View': 2,
#  'New Bothwell is a community in the Rural Municipality of Hanover, Manitoba, Canada': 2,
#  'Budia is a municipality located in the province of Guadalajara, Castile-La Mancha, Spain': 2,
#  'Tachibana was a town located in Yame District, Fukuoka Prefecture, Japan': 2,
#  'Carral is a municipality of northwestern Spain in the province of A Coruña, in the autonomous community of Galicia': 2,
#  'Paradela is a municipality in Lugo province in Galicia in north-west Spain': 2,
#  'Basse-Terre is the prefecture of Guadeloupe, an overseas region and department of France located in the Lesser Antilles': 2,
#  'Bafarara is a village and principal settlement of the commune of Sahel in the Cercle of Kayes in the Kayes Region of south-western Mali': 2,
#  'Nikolsk is a town and the administrative center of Nikolsky District in Penza Oblast, Russia, located on the Vyrgan River 120 kilometers northeast of Penza,': 2,
#  'Nambroca is a municipality located in the province of Toledo, Castile-La Mancha, Spain': 2,
#  'Nagos': 2,
#  'Kogota was a town located in Tōda District, Miyagi Prefecture, Japan': 2,
#  'Boton is a settlement on the island of Aruba, located towards the south-center of the island': 2,
#  'Bittern Lake, originally named Rosenroll, is a village in central Alberta, Canada': 2,
#  "N’Guyakro is a town and commune in the Didiévi Department, Côte d'Ivoire": 2,
#  'Dorothy Stirling Subdivision': 2,
#  'Dougoufie is a small town and commune in the Cercle of Barouéli in the Ségou Region of southern-central Mali': 2,
#  'Gōtsu is a city located in Shimane Prefecture, Japan': 2,
#  "South River is a town in the Canadian province of Newfoundland and Labrador, located at the junction of Cupids, Roaches Line, Makinsons and Clarke's Beach": 2,
#  'Sennan is a city located in Osaka Prefecture, Japan': 2,
#  'Sakado is a city located in Saitama Prefecture, Japan': 2,
#  'Burdett is a hamlet in Alberta, Canada within the County of Forty Mile No': 2,
#  'Kawane was a town located in Haibara District, Shizuoka Prefecture, Japan': 2,
#  'Nanyo is a city in Yamagata Prefecture, Japan': 2,
#  'Naperville Township is one of nine townships in DuPage County, Illinois, USA': 2,
#  'Belltower': 2,
#  'Candelaria is a municipality and town in the Artemisa Province of Cuba': 2,
#  'Allens Grove Township is located in Mason County, Illinois': 2,
#  'Palma Real is a Sector in the city of Santo Domingo in the Distrito Nacional of the Dominican Republic': 2,
#  'Sakamoto was a village located in Yatsuhiro District, Kumamoto Prefecture, Japan': 2,
#  'Sol-Iletsk is a town in Orenburg Oblast, Russia, located on the right bank of the Ilek River, 77 kilometers south of Orenburg, the administrative center': 2,
#  'Beas is a municipality located in the province of Huelva, Spain': 2,
#  'Kameshkovo is a town and the administrative center of Kameshkovsky District of Vladimir Oblast, Russia, located 41 kilometers northeast of Vladimir, the administrative center of': 2,
#  'Guidimé is a rural commune in the Cercle of Yélimané in the Kayes Region of western Mali': 2,
#  'New Year': 2,
#  'Sanpoku was a town located in Iwafune District, Niigata Prefecture, Japan': 2,
#  'El Oso is a municipality in the Spanish province of Ávila, in the autonomous community of Castile-Leon': 2,
#  'Mount Moriah is a town in the Canadian province of Newfoundland and Labrador': 2,
#  'Gdov is a town and the administrative center of Gdovsky District in Pskov Oblast, Russia, located on the Gdovka River, just 2 kilometers from its': 2,
#  'Ogle': 2,
#  'Atkinson Township is one of twenty-four townships in Henry County, Illinois, USA': 2,
#  'West Chandler': 2,
#  'Prado is a Spanish municipality in the province of Zamora, Castile and León': 2,
#  'Kulusuk, formerly Kap Dan, is a settlement in the Sermersooq municipality in southeastern Greenland, located on an island of the same name': 2,
#  'Benalúa de las Villas is a city located in the province of Granada, Spain': 2,
#  'Durand Township is located in Winnebago County, Illinois': 2,
#  'Eightmile Saddle': 2,
#  'Gladmar is a dissolved village in the Canadian province of Saskatchewan located 2 kilometres north of Highway 18 as it runs east from Highway 6': 2,
#  "Biasso is a town and commune in the Adzopé Department, Côte d'Ivoire": 2,
#  'Brook Village is a rural community in the County of Inverness, Cape Breton, Nova Scotia': 2,
#  'Chinameca is a municipality in the San Miguel Department of El Salvador': 2,
#  'Whites City': 2,
#  'Tindirma is a village and commune of the Cercle of Diré in the Tombouctou Region of Mali': 2,
#  'Ould Yenge is a town and commune in Mauritania': 2,
#  'Cranbrook is a city in southeast British Columbia, located on the west side of the Kootenay River at its confluence with the St': 2,
#  "Mbalal or M'Balel is a town and urban commune in the Trarza Region of south-western Mauritania": 2,
#  'Quast': 2,
#  'Virginia City is a town in and the county seat of Madison County, Montana, United States': 2,
#  'Caso is a municipality in the Spanish Principality of Asturias': 2,
#  'East Gwillimbury is a town on the East Holland River in the Regional Municipality of York': 2,
#  'The Cottage': 2,
#  'Reyðarfjörður is a town in Iceland': 2,
#  'Songoyah is a town and sub-prefecture in the Faranah Prefecture in the Faranah Region of Guinea': 2,
#  'Gird Point': 2,
#  'Gunsight': 2,
#  'Rhodes': 2,
#  'Lark Harbour is small fishing community on the western coast of Newfoundland, on the south side of the Bay of Islands, and west of the': 2,
#  'Florence Township is located in Will County, Illinois': 2,
#  "Guéyo is a town and commune in Côte d'Ivoire": 2,
#  'Maiden': 2,
#  'New Douglas Township is located in Madison County, Illinois, in the United States': 2,
#  'East Mesa': 2,
#  'Ross Township is located in Pike County, Illinois': 2,
#  'Ouanaminthe is a commune located in the Nord-Est Department of Haiti': 2,
#  "The Confederation Park subdivision of Saskatoon, Saskatchewan, Canada, is located west of the South Saskatchewan River, Saskatoon's west side": 2,
#  'Ide is a town located in Tsuzuki District, Kyoto Prefecture, Japan': 2,
#  "St. George's is a Canadian community in the province of Newfoundland and Labrador\\nThe town is located on the west coast of Newfoundland in the St": 2,
#  'Soledad de Graciano Sánchez is the second-largest city of the state of San Luis Potosí in Mexico': 2,
#  'Polebridge is an unincorporated community in Flathead County, Montana, United States, 35 miles northwest of Columbia Falls in the northwestern part of the state': 2,
#  'Tekoulo is a town and sub-prefecture in the Guéckédou Prefecture in the Nzérékoré Region of south-western Guinea': 2,
#  'Inagi is a city located in Tokyo Metropolis, Japan': 2,
#  'Romeoville is a village in Will County, Illinois, United States': 2,
#  "Téhini is a town and commune in Côte d'Ivoire": 2,
#  'Forest City Township is located in Mason County, Illinois': 2,
#  'Tiñosillos is a municipality located in the province of Ávila, Castile and León, Spain': 2,
#  'Long Wittenham is a village and civil parish about 3 miles north of Didcot, and 3': 2,
#  'San Andrés Cohamiata is an autonomously governed Wixárika village located in Mezquitic, Jalisco, Mexico': 2,
#  "Ottawa is a town and commune in the Soubré Department, Côte d'Ivoire": 2,
#  'Taliverde': 2,
#  'Francis Avent Gumm was a vaudeville performer': 2,
#  'Tagami is a town located in Minamikanbara District, Niigata Prefecture, Japan': 2,
#  'Kafo Faboli is a commune in the Cercle of Koutiala in the Sikasso Region of southern Mali': 2,
#  'Afolkey is an unincorporated community in Stephenson County, Illinois': 2,
#  'Woodbridge Crossing': 2,
#  'Borzya is a town and the administrative center of Borzinsky District in Zabaykalsky Krai, Russia, located 349 kilometers southeast of Chita, the administrative center of': 2,
#  'Star': 2,
#  'Aguacatán is a municipality in the Guatemalan department of Huehuetenango': 2,
#  "Bondo, Côte d'Ivoire is a town and commune in Côte d'Ivoire": 2,
#  'Rieder': 2,
#  'Drakino is a rural locality in Liskinsky District of Voronezh Oblast, Russia': 2,
#  'Sebba is a town located in the province of Yagha in Burkina Faso': 2,
#  'Pineridge is a neighbourhood in Northeast Calgary, Alberta, Canada, and is one of four neighbourhoods that make up what is called the Properties, along with': 2,
#  'Valentine Manor': 2,
#  'Poboleda is a village in the province of Tarragona and autonomous community of Catalonia, Spain': 2,
#  'Yorkfield': 2,
#  'Leisure World Arizona is a gated, resort style adult community located in Mesa, Arizona': 2,
#  "L'Eliana is a municipality in the comarca of Camp de Túria in the Valencian Community, Spain": 2,
#  'Fatiné is a rural commune in the Cercle of Ségou in the Ségou Region of Mali': 2,
#  'Villalpardo is a municipality located in the province of Cuenca, Castile-La Mancha, Spain': 2,
#  'Nizhniye Sergi is a town and the administrative center of Nizhneserginsky District in Sverdlovsk Oblast, Russia, located on a rolling plain surrounded by the Ural': 2,
#  "Affiénou is a town and commune in Côte d'Ivoire": 2,
#  'Syasstroy is a town in Volkhovsky District of Leningrad Oblast, Russia, located near the mouth of the Syas River, at its confluence with the Valgonka,': 2,
#  'Winthrop Harbor Station': 2,
#  'Niitsuru was a village located in Ōnuma District, Fukushima Prefecture, Japan': 2,
#  'Rodden is an unincorporated community located in Elizabeth Township, Jo Daviess County, Illinois, United States': 2,
#  'Sulima is a chiefdom in Koinadugu District of Sierra Leone with a population of 20,062': 2,
#  '6247411': 2,
#  "Ponondougou is a town and commune in Côte d'Ivoire": 2,
#  'Poplars Trailer Court': 2,
#  'Lanesville': 2,
#  'Big Sandy Trailer Court': 2,
#  'Hachimantai is a city located in Iwate Prefecture, Japan': 2,
#  'Golag is a village in the Tibet Autonomous Region of China': 2,
#  "Diamarakro is a town and commune in Côte d'Ivoire": 2,
#  'Capesterre-de-Marie-Galante is a commune on the island of Marie-Galante, in the French overseas region and department of Guadeloupe, itself in the Lesser Antilles': 2,
#  "Iboguhé is a town and commune in the Issia Department, Côte d'Ivoire": 2,
#  'Les Abymes is the most populated commune in the French overseas region and department of Guadeloupe, in the Lesser Antilles': 2,
#  'Boadilla del Camino is a municipality located in the province of Palencia, Castile and León, Spain': 2,
#  'Tecate is a small city in Baja California, Mexico and the municipal seat of Tecate Municipality': 2,
#  'Medicine Hot Springs': 2,
#  'Legrane is a town and commune in Mauritania': 2,
#  'Ford': 2,
#  'Sonai': 2,
#  'Lac-Nilgaut is a vast unorganized territory in the Outaouais region, Quebec, Canada': 2,
#  'Willow Grove': 2,
#  'Torahime was a town located in Higashiazai District, Shiga Prefecture, Japan': 2,
#  'San Marcos is a municipality in the Carazo Department of Nicaragua': 2,
#  'Yolo is a village and seat of the commune of Diédougou in the Cercle of Ségou in the Ségou Region of southern-central Mali': 2,
#  'Moussadou is a town and sub-prefecture in the Beyla Prefecture in the Nzérékoré Region of south-eastern Guinea': 2,
#  'Naouya is a town in the Fara Department of Balé Province in southern Burkina Faso': 2,
#  "Madinani is the chief town and commune in the greater Madinani Department, Côte d'Ivoire": 2,
#  '5231438': 2,
#  "Grand-Morié is a town and commune in the Agboville Department, Côte d'Ivoire": 2,
#  'Koumbia is a village and commune in the Cercle of Yorosso in the Sikasso Region of southern Mali': 2,
#  'Little Oklahoma': 2,
#  'Estates of Indian Creek': 2,
#  'Rylsk is a town and the administrative center of Rylsky District in Kursk Oblast, Russia, located on the right bank of the Seym River 124': 2,
#  'Matsubase was a town located in Shimomashiki District, Kumamoto Prefecture, Japan': 2,
#  'Momence is a city in Kankakee County, Illinois, United States': 2,
#  'Cristo Rey is a Sector in the city of Santo Domingo in the Distrito Nacional of the Dominican Republic': 2,
#  'Mikladalur is the largest of four villages on the Faroese island of Kalsoy in the municipality of Klaksvíkar': 2,
#  "Kimbirila-Nord is a village of the department of Minignan, Denguélé Region, Côte d'Ivoire": 2,
#  'Minamitane is a town located on Tanegashima, in Kumage District, Kagoshima Prefecture, Japan': 2,
#  'Komagane is a city located in Nagano Prefecture, Japan': 2,
#  'Elvillar is a town and municipality located in the province of Álava, in the Basque Country, northern Spain': 2,
#  'Yachimata is a city in northern Chiba Prefecture, Japan': 2,
#  "Morondo is a town and commune in Côte d'Ivoire": 2,
#  'Canyon View': 2,
#  'Yamato is a city located in central Kanagawa Prefecture, Japan': 2,
#  'Simpson': 2,
#  "Olodio is a town and commune in the Tabou Department, Côte d'Ivoire": 2,
#  'Eskifjörður, or also Eskifjördur, is a town and port in eastern Iceland with a large fishing industry': 2,
#  'Burlington Township is located in Kane County, Illinois': 2,
#  'Shacheng': 2,
#  'Flynn': 2,
#  'Bruno': 2,
#  'Burton Township is the smallest in area in McHenry County, Illinois': 2,
#  'Royal Estates West': 2,
#  'Minamiizu is a town located at the southern tip of Izu Peninsula in Kamo District, Shizuoka Prefecture, Japan': 2,
#  'Ishikawa was a city located in Okinawa Prefecture, Japan': 2,
#  'Bohemian California': 2,
#  'Torreorgaz is a municipality located in the province of Cáceres, Extremadura, Spain': 2,
#  'Udina is an unincorporated community in Plato Township, Kane County, Illinois': 2,
#  "Zébouo Nord is a town and commune in the Zoukougbeu Department, Côte d'Ivoire": 2,
#  'Zaraysk is a town and the administrative center of Zaraysky District in Moscow Oblast, Russia, located about 162 kilometers southeast from Moscow': 2,
#  'Kaala is a town and sub-prefecture in the Dalaba Prefecture in the Faranah Region of western Guinea': 2,
#  'Janney': 2,
#  'Almora Heights': 2,
#  'Liberty is a small unincorporated community in Maricopa County, Arizona, United States': 2,
#  'Volchansk is a town under the administrative jurisdiction of the Town of Karpinsk in Sverdlovsk Oblast, Russia, located on the Volchanka River, 452 kilometers north': 2,
#  'Niniongo is a village in the Zimtenga Department of Bam Province in northern-central Burkina Faso': 2,
#  'Huson is a census-designated place and unincorporated community in Missoula County, Montana, United States': 2,
#  'Gartside': 2,
#  'The Resort Village of the District of Katepwa is a resort village that includes many of the cottages that can be found along Katepwa Lake': 2,
#  'Ocoya': 2,
#  'Cayuela is a municipality located in the province of Burgos, Castile and León, Spain': 2,
#  'Argolibio is a parish in Amieva, a municipality within the province and autonomous community of Asturias, in northern Spain': 2,
#  'Yoshikawa is a city located in Saitama Prefecture, Japan': 2,
#  'Lexington is a former settlement in Edwards County, Illinois, United States': 2,
#  'Wola is a small town and commune in the Cercle of Bougouni in the Sikasso Region of south-western Mali': 2,
#  'Katav-Ivanovsk is a town and the administrative center of Katav-Ivanovsky District in Chelyabinsk Oblast, Russia, located on the Katav River, 321 kilometers southwest of Chelyabinsk,': 2,
#  'Princeville Township is located in Peoria County, Illinois': 2,
#  'Monistrol de Montserrat is a municipality in the comarca of the Bages in Catalonia, Spain': 2,
#  'Hino is a city located in central Tokyo Metropolis, Japan': 2,
#  'Porkhov is a town and the administrative center of Porkhovsky District in Pskov Oblast, Russia, located on the Shelon River, 75 kilometers east of Pskov,': 2,
#  'Sijiu is a town in the southwest of Guangdong province in Southern China': 2,
#  'Pana, Burkina Faso is a village in the Pompoï Department of Balé Province in southern Burkina Faso, Africa': 2,
#  'Marshall Township is one of fifteen townships in Clark County, Illinois, USA': 2,
#  'Yorba Linda is a suburban city in northeastern Orange County, California, approximately 13 miles northeast of Downtown Santa Ana and 37 miles southeast of Downtown': 2,
#  'Bausen is a municipality in the comarca of the Aran Valley in Catalonia, Spain, close to the French border': 2,
#  'Unionville is an unincorporated community in Lewis and Clark County, Montana, United States four miles south of Helena, Montana and about 2 miles West of': 2,
#  'Glenburnie-Birchy Head-Shoal Brook is a town in the Canadian province of Newfoundland and Labrador': 2,
#  'Morgenster is a village on the island of Aruba, located towards the center of the island': 2,
#  'Louiseville is a town in the Mauricie region of the province of Quebec in Canada': 2,
#  'Palmas Royale': 2,
#  'Toyosato is a town located in Inukami District, Shiga Prefecture, Japan': 2,
#  'Castroverde de Cerrato is a municipality located in the province of Valladolid, Castile and León, Spain': 2,
#  'Paragon': 2,
#  'Bancoumana or Bankoumana is a small town and rural commune in the Cercle of Kati in the Koulikoro Region of south-western Mali': 2,
#  '5570045': 2,
#  'Sanjō is a city located in Niigata Prefecture, Japan': 2,
#  'Ivanhoe is a small unincorporated community in Lake County, Illinois, United States near Mundelein, Illinois': 2,
#  'Lolo Peak Trailer Court': 2,
#  'El Royo is a municipality located in the province of Soria, Castile and León, Spain': 2,
#  'Lustre': 2,
#  'Bishops Ridge': 2,
#  'Skokie Manor': 2,
#  'Cascajares de Bureba is a municipality located in the province of Burgos, Castile and León, Spain': 2,
#  'The Fields': 2,
#  "Vao is a town and commune in the Zoukougbeu Department, Côte d'Ivoire": 2,
#  'Risk': 2,
#  "Kasséré is a town and commune in Côte d'Ivoire": 2,
#  'Wurtz Hill': 2,
#  'Dudley': 2,
#  'Jarvis Township is located in Madison County, Illinois, in the United States': 2,
#  'Nishiki was a town located in Kuga District, Yamaguchi Prefecture, Japan': 2,
#  'Sasalbé is a commune in the Cercle of Mopti in the Mopti Region of Mali': 2,
#  'Neunert': 2,
#  'Wasson is an unincorporated community in East Eldorado and Raleigh Townships, Saline County, Illinois, United States': 2,
#  'Henton': 2,
#  'Duntara is a town located north west of Catalina, Newfoundland and Labrador': 2,
#  'Cushman': 2,
#  'Saint-Patrice-de-Sherrington is a municipality in Les Jardins-de-Napierville Regional County Municipality in Quebec, Canada, situated in the Montérégie administrative region': 2,
#  'Millville': 2,
#  'Coynes': 2,
#  'Tomari was a village located in Tōhaku District, Tottori Prefecture, Japan': 2,
#  "Rosetta is a port city of the Nile Delta, located 65 km east of Alexandria, in Egypt's Beheira governorate": 2,
#  'Takahata is a town located in Higashiokitama District, Yamagata Prefecture, Japan': 2,
#  "Kotronou is a town and commune in Côte d'Ivoire": 2,
#  'Sunrise Trailer Court': 2,
#  'Tosa is a city located in Kōchi Prefecture, Japan': 2,
#  'Troy is a city in Madison County, Illinois, United States': 2,
#  'Cape Coast, or Cabo Corso, is a city and fishing port, and the capital of Cape Coast Metropolitan District and Central Region of south Ghana': 2,
#  'Akhtubinsk is a town and the administrative center of Akhtubinsky District in Astrakhan Oblast, Russia, located on the left bank of the Akhtuba River, 292': 2,
#  'Nongoa is a town and sub-prefecture in the Guéckédou Prefecture in the Nzérékoré Region of south-western Guinea': 2,
#  'Damankanyah is a town and sub-prefecture in the Kindia Prefecture in the Kindia Region of western Guinea': 2,
#  'North Mounds': 2,
#  'Gallants is located northeast of Stephenville, Newfoundland and Labrador, Canada': 2,
#  'Fosston is a village in the rural municipality of Ponass Lake No': 2,
#  'Bihoro is a town located in Abashiri District, Okhotsk Subprefecture, Hokkaido, Japan': 2,
#  'Conchagua is a municipality in the La Unión department of El Salvador': 2,
#  'Kyōtanabe is a city located in the southern tip of Kyoto Prefecture, Japan': 2,
#  'Gilberts is a village in Kane County, Illinois, United States': 2,
#  'Funaoka was a town located in Yazu District, Tottori Prefecture, Japan': 2,
#  'Tabasco is a small town in the state of Zacatecas, Mexico': 2,
#  'Onzonilla is a municipality located in the province of León, Castile and León, Spain': 2,
#  'Melnikovo is a settlement on Karelian Isthmus, in Priozersky District of Leningrad Oblast': 2,
#  'Bolbaite is a municipality in the comarca of Canal de Navarrés in the Valencian Community, Spain': 2,
#  'Jidr-El Mouhguen or Jedr El Moubghuen is a town and urban commune in the Trarza Region of south-western Mauritania': 2,
#  'Fanlo is a municipality located in the province of Huesca, Aragon, Spain': 2,
#  'Atsumi was a town located in Nishitagawa District, Yamagata Prefecture, Japan': 2,
#  'Lebredo is a parish in the municipalities of Boal, Coaña, and El Franco, within the province and autonomous community of Asturias, in northern Spain': 2,
#  "M’possa is a town and commune in Côte d'Ivoire": 2,
# ...
#  'Liguanea is an area of the island of Jamaica in the West Indies': 2,
#  'Tracadie–Sheila is a former town in Gloucester County, New Brunswick, Canada': 2,
#  "Kouétinfla is a town and commune in Côte d'Ivoire": 2,
#  'Yuzha is a town and the administrative center of Yuzhsky District in Ivanovo Oblast, Russia, located on Lake Vazal, 95 kilometers southeast of Ivanovo, the': 2,
#  'Elburn is a village in Kane County, Illinois, United States': 2,
#  'Utah': 2,
#  'Cleveland is a village in Henry County, Illinois, United States': 2,
#  'Silver Glen Meadows': 2,
#  'Samayah is a town and sub-prefecture in the Kindia Prefecture in the Kindia Region of western Guinea': 2,
#  'Cheltenham is a station on the Hyde Park/South Chicago branch of the Metra Electric Line': 2,
#  'Dorrisville': 2,
#  'Nelsons Trailer Court': 2,
#  'Fort Negley was a fortification built for the American Civil War, located approximately 2-mile south of downtown Nashville, Tennessee': 2,
#  'Elso': 2,
#  'Setouchi is a town located primarily on Amami Ōshima, in Ōshima District, Kagoshima Prefecture, Japan': 2,
#  'Rio Vista Village is the newest of the fifteen urban villages of Phoenix, Arizona, located far to the north of the rest of the city': 2,
#  'Keller': 2,
#  'Oil Springs is a village in Lambton County, Ontario, Canada, located along Former Provincial Highway 21 south of Oil City': 2,
#  'Bougouni is a village and seat of the commune of Mariko in the Cercle of Niono in the Ségou Region of southern-central Mali': 2,
#  "Férémandougou is a town and commune in the Odienné Department, Côte d'Ivoire": 2,
#  'Kanagi was a town located in Naka District, Shimane Prefecture, Japan': 2,
#  'Cassidy Curve': 2,
#  'Aylsham is a village in east-central Saskatchewan, Canada, approximately 65 km northeast of Melfort': 2,
#  'Estubeny is a municipality in the comarca of Costera in the Valencian Community, Spain': 2,
#  'Sahuayo is a city in the state of Michoacán, in western México, near the southern shore of Lake Chapala': 2,
#  'Yura is a town located in Hidaka District, Wakayama Prefecture, Japan': 2,
#  'Portmore is a large coastal city in southern Jamaica in Saint Catherine, and a dormitory town for the neighbouring cities of Kingston and Spanish Town': 2,
#  'Caldes de Malavella is a municipality of the comarca of Selva in Catalonia, Spain': 2,
#  '2041000': 2,
#  'Ragged Point is a village in Saint Philip Parish in Barbados': 2,
#  'Diouloulou Arrondissement is an arrondissement of the Bignona Department in the Ziguinchor Region of Senegal': 2,
#  'Albazino is a village in Skovorodinsky District of Amur Oblast, Russia, noted as the site of Albazin, the first Russian settlement on the Amur River': 2,
#  'Castellvell del Camp is a village in the province of Tarragona and autonomous community of Catalonia, Spain': 2,
#  'Logan is an unincorporated community in Gallatin County, Montana, United States': 2,
#  'Zavodoukovsk is a town in Tyumen Oblast, Russia, located on the Bolshoy Uk River 96 kilometers southeast of Tyumen': 2,
#  'Neftekumsk is a town and the administrative center of Neftekumsky District in Stavropol Krai, Russia, located on the right bank of the Kuma River, 305': 2,
#  'Hillsdale is a village in Rock Island County, Illinois, United States': 2,
#  'Stenen is a village in the Canadian province of Saskatchewan': 2,
#  'Labytnangi is a town in Yamalo-Nenets Autonomous Okrug, Russia, located on the left bank of the Ob River, 20 kilometers northwest of Salekhard': 2,
#  'Wasco was a former unincorporated community in Kane County, Illinois, United States': 2,
#  'Oasis Mobile Home Park': 2,
#  'Larrodrigo is a municipality located in the province of Salamanca, Castile and León, Spain': 2,
#  'Huéscar is a municipality of the province of Granada, Spain': 2,
#  'Ferrier is a commune in the Fort-Liberté Arrondissement, in the Nord-Est Department of Haiti': 2,
#  'Garambé is a town and sub-prefecture in the Labé Prefecture in the Labé Region of northern-central Guinea': 2,
#  'Nirasaki is a city in central Yamanashi Prefecture, Japan': 2,
#  'Nakagawa was a town located in Naka District, Tokushima Prefecture, Japan': 2,
#  'Monroy is a municipality located in the province of Cáceres, Extremadura, Spain': 2,
#  'Goryachy Klyuch is a town and a balneological resort in Krasnodar Krai, Russia, located on the Psekups River 65 kilometers south of Krasnodar, the administrative': 2,
#  'Three Rock Cove is a village located northwest of Stephenville, Newfoundland and Labrador': 2,
#  'Pelarrodríguez is a municipality located in the province of Salamanca, Castile and León, Spain': 2,
#  'Gougoudjé is a town and sub-prefecture in the Télimélé Prefecture in the Kindia Region of western-central Guinea': 2,
#  'Kulebaki is a town and the administrative center of Kulebaksky District in Nizhny Novgorod Oblast, Russia, located 188 kilometers southwest of Nizhny Novgorod, the administrative': 2,
#  'Azat is a small village in the Gegharkunik Province of Armenia': 2,
#  'Marines is a municipality in the comarca of Camp de Túria in the Valencian Community, Spain': 2,
#  'Waterloo is a municipality in the province of Walloon Brabant, Belgium, which in 2011 had a population of 29,706 and an area of 21': 2,
#  'Murphysboro is a city in and the county seat of Jackson County, Illinois, United States': 2,
#  'Central Butte is a town in Saskatchewan, Canada, approximately 200 kilometres from Saskatoon, Regina and Swift Current and 100 kilometres from Moose Jaw': 2,
#  "Kondossou is a town and commune in Côte d'Ivoire": 2,
#  'Pravdino is a settlement on the Karelian Isthmus, in Vyborgsky District of Leningrad Oblast': 2,
#  'Independence': 2,
#  'Tateyama is a town located in Nakaniikawa District, Toyama Prefecture, Japan': 2,
#  'Lake View Highlands': 2,
#  'Sunfield is an unincorporated community in Perry County, Illinois, United States': 2,
#  'Odaka was a town located in Sōma District, Fukushima, Japan': 2,
#  'Lake McDonald is an unincorporated community in Flathead County, Montana, United States': 2,
#  'Mihama is a town located in Hidaka District, Wakayama Prefecture, Japan': 2,
#  'Rockvale Township is located in Ogle County, Illinois': 2,
#  'Old Colony Court': 2,
#  'Zaporozhskoye is a settlement on Karelian Isthmus, in Priozersky District of Leningrad Oblast': 2,
#  'Marlborough Park is a residential neighbourhood in the north-east quadrant of Calgary, Alberta': 2,
#  'Abadiño is a town located in the province of Biscay, in the autonomous community of Basque Country, in the north of Spain, about 35 km': 2,
#  'Sherwood Oaks': 2,
#  "Teulada is a small coastal town on Spain's Costa Blanca, located 3 km north from Junction 63 of the A7 E-15 toll motorway on the": 2,
#  'Walnut Grove is a city in Redwood County, Minnesota, United States': 2,
#  'Schusters Place': 2,
#  'Asakita-ku is one of the eight wards of the city of Hiroshima': 2,
#  'Torralba de Ribota is a municipality located in the province of Zaragoza, Aragon, Spain': 2,
#  'Arbor Creek': 2,
#  'Santa Eulàlia de Riuprimer is a municipality in the comarca of Osona in Catalonia, Spain': 2,
#  'White Tanks': 2,
#  'Irondale': 2,
#  'South Commons': 2,
#  'Briergate': 2,
#  'Williams Park': 2,
#  'Howardton': 2,
#  "Kouassi-N’Dawa is a town and commune in Côte d'Ivoire": 2,
#  'Artyomovsk is a town in Kuraginsky District of Krasnoyarsk Krai, Russia, located 180 kilometers south of Krasnoyarsk': 2,
#  'Newcomb': 2,
#  'Rural Township is located in Shelby County, Illinois': 2,
#  'University Heights': 2,
#  'Gatika is a town and municipality located in the province of Biscay, in the autonomous community of Basque Country, northern Spain': 2,
#  'San Juan is a town in Trinidad and Tobago': 2,
#  'Taft is a ghost town in Mineral County, Montana, United States': 2,
#  'Peters Creek is an unincorporated community in Hardin County, Illinois, United States': 2,
#  'Abbey is a village within rural municipality Miry Creek No': 2,
#  'Oakton': 2,
#  "Aššur, also known as Ashur, Qal'at Sherqat and Kalah Shergat, is a remnant city of the last Ashurite Kingdom": 2,
#  'Castejón de Monegros is a municipality located in the province of Huesca, Aragon, Spain': 2,
#  'Tingole is a village and seat of the commune of Binko in the Cercle of Dioila in the Koulikoro Region of south-western Mali': 2,
#  'Bond Township is located in Lawrence County, Illinois': 2,
#  'Dryer Place': 2,
#  'Almazán is a municipality located in the province of Soria, Castile and León, Spain': 2,
#  'Shrewsbury is the county town of Shropshire, England': 2,
#  'Miramichi [ˈmɛɚˌməˌʃi] is the largest city in northern New Brunswick, Canada': 2,
#  'Zakamensk is a town and the administrative center of Zakamensky District of the Republic of Buryatia, Russia, located on the Dzhida River 420 kilometers southwest': 2,
#  'Becks Park': 2,
#  'Fukue was a village located in Abu District, Yamaguchi Prefecture, Japan': 2,
#  'Daghveg is a town and commune in Mauritania': 2,
#  "Memni is a town and commune in Côte d'Ivoire": 2,
#  'Diaye Coura is a small town and commune in the Cercle of Nioro in the Kayes Region of western Mali': 2,
#  'Maaden is a village and rural commune in Mauritania': 2,
#  'Newton': 2,
#  'San Adrián is a town and municipality located in the province and autonomous community of Navarre, northern Spain': 2,
#  'New Chicago': 2,
#  'Mount Hope Township is located in McLean County, Illinois': 2,
#  'Guazapa is a municipality in the San Salvador department of El Salvador': 2,
#  'Hillhurst is a northwest neighbourhood located within the inner city of Calgary, Alberta, Canada': 2,
#  "M'Bouna is a village and commune of the Cercle of Goudam in the Tombouctou Region of Mali": 2,
#  'DY Junction': 2,
#  'Saint-Paulin is a municipality in the Mauricie region of the province of Quebec in Canada': 2,
#  "Dongzhou is a coastal village in China's southern Guangdong province, in the Chengqu District of the prefecture-level city of Shanwei": 2,
#  'Leninsk is a town and the administrative center of Leninsky District in Volgograd Oblast, Russia, located on the left bank of the Akhtuba River, 78': 2,
#  'Birkner is a populated area in St': 2,
#  'Lakeview': 2,
#  'Behchokǫ̀, officially the Tłı̨chǫ Community Government of Behchokǫ̀, is a community in the North Slave Region of the Northwest Territories, Canada': 2,
#  'Dunleith Township is one of twenty-three townships in Jo Daviess County, Illinois, USA': 2,
#  'Burlington is an incorporated town in Newfoundland and Labrador, Canada': 2,
#  'Grays Corner': 2,
#  'Trinidad de Copán is a municipality in the Honduran department of Copán': 2,
#  'Richwoods Township is located in Peoria County, Illinois': 2,
#  'Cabaret is a commune in the Arcahaie Arrondissement, in the Ouest Department of Haiti': 2,
#  'Roales de Campos is a municipality located in the province of Valladolid, Castile and León, Spain': 2,
#  'Batiscan is a municipality in the Mauricie region of the province of Quebec in Canada': 2,
#  "Koroumba is a town and commune in the Madinani Department, Côte d'Ivoire": 2,
#  'Ōbu is a city located in Aichi Prefecture, Japan': 2,
#  'Sidi Barrani is a town in Egypt, near the Mediterranean Sea, about 95 km east of the border with Libya, and around 240 km from': 2,
#  'Markham': 2,
#  'Bangoueta is a village in the Nzérékoré Prefecture in the Nzérékoré Region of south-eastern Guinea': 2,
#  'Setoda was a town located in Toyota District, Hiroshima Prefecture, Japan': 2,
#  'Trujillanos is a Spanish municipality in the province of Badajoz, Extremadura': 2,
#  'Roturas is a municipality located in the province of Valladolid, Castile and León, Spain': 2,
#  'Provost is a town in central Alberta, Canada': 2,
#  'Minano is a town located in Chichibu District, Saitama Prefecture, Japan': 2,
#  'Plan de Sánchez is a village in the municipality of Rabinal, Baja Verapaz department, Guatemala': 2,
#  'Shiribana is a village on the island of Aruba, located towards the center of the island': 2,
#  'Winnipeg Beach is a town in the Interlake Region, in the Canadian province of Manitoba': 2,
#  'Tsukiyono was a town located in Tone District, Gunma Prefecture, Japan': 2,
#  'Casa de Francisco Mobile Home Park': 2,
#  'Gilead Precinct is located in Calhoun County, Illinois': 2,
#  'Cuajinicuilapa Municipality is one of the 81 municipalities of Guerrero, in south-western Mexico': 2,
#  'Media Township is one of eleven townships in Henderson County, Illinois, USA': 2,
#  'Saint-Sylvère is a municipality in the Centre-du-Québec region of the province of Quebec in Canada': 2,
#  "Bishop's Falls is a Canadian town in the north-central part of the island of Newfoundland in the province of Newfoundland and Labrador, with a population": 2,
#  'Wolf Creek Estates': 2,
#  'Ravenswood Place': 2,
#  'Sombra is a village situated on the St': 2,
#  'Rouleau is a town in southern Saskatchewan, Canada located in a rural region known as the Breadbasket of Canada': 2,
#  'Green Castle': 2,
#  'Parkside is a village in the Canadian province of Saskatchewan': 2,
#  'Porédaka is a town and sub-prefecture in the Mamou Prefecture in the Mamou Region of Guinea': 2,
#  'Mutsuzawa is a town located in Chōsei District, Chiba Prefecture, Japan': 2,
#  'Susinos del Páramo is a municipality and town located in the province of Burgos, Castile and León, Spain': 2,
#  "Koumassi is a town and commune in Abidjan, Côte d'Ivoire": 2,
#  'Kalagré-mossi is a village in the Zimtenga Department of Bam Province in northern-central Burkina Faso': 2,
#  'Fravert': 2,
#  'Lizartza is a town located in the province of Gipuzkoa, in the autonomous community of Basque Country, in the North of Spain': 2,
#  'Pinehurst Manor': 2,
#  'Madison Station': 2,
#  'Mid-North District': 2,
#  'Kapisillit is a settlement in the Sermersooq municipality in southwestern Greenland': 2,
#  'Barnoldswick is a town and civil parish in Lancashire, England': 2,
#  'Capitol Hill is a residential neighbourhood in the north-west quadrant of Calgary, Alberta': 2,
#  'Nangō was a former village located in Minamiaizu District, Fukushima Prefecture, Japan': 2,
#  'Rionegro del Puente is a municipality located in the province of Zamora, Castile and León, Spain': 2,
#  "Segeda is an ancient settlement, near today's Zaragoza in modern-day Spain": 2,
#  'Bath is a small village on the island of Nevis, in Saint Kitts and Nevis': 2,
#  'Bald Bluff': 2,
#  'Hutton Township is one of twelve townships in Coles County, Illinois, USA': 2,
#  'Kahoku is a city in Ishikawa Prefecture, Japan': 2,
#  'Neville is a small village of around 80 citizens and is located on Highway 43': 2,
#  'Hosoiri was a village located in Nei District, Toyama Prefecture, Japan': 2,
#  'Volcán is a town and corregimiento in Tierras Altas District, Chiriquí Province, Panama': 2,
#  'Torremontalbo is a village in the province and autonomous community of La Rioja, Spain': 2,
#  'Millstadt Junction': 2,
#  'Mitsue is a village located in Uda District, Nara Prefecture, Japan': 2,
#  'Fanny Bay is a small hamlet in the Canadian province of British Columbia': 2,
#  'Ijevan, is a town in Armenia and the administrative centre of the Tavush Province': 2,
#  'Elk Point is a town located in east-central Alberta, Canada': 2,
#  'Dioila is a small town and seat of the commune of Kaladougou in the Cercle of Dioila in the Koulikoro Region of south-western Mali': 2,
#  'Makurazaki is a city located in Kagoshima Prefecture, Japan': 2,
#  'Kisbey is a village in southern Saskatchewan, Canada': 2,
#  'Rybachy, before 1946 known as Rossitten in East Prussia, is a rural settlement in Zelenogradsky District of Kaliningrad Oblast, Russia, located on the Curonian Spit': 2,
#  'Yumesaki was a town located in Shikama District, Hyōgo Prefecture, Japan': 2,
#  'Orenburg is a transcontinental city and the administrative center of Orenburg Oblast, Russia, located on the Ural River 1,478 kilometers southeast of Moscow, very close': 2,
#  'Shizugawa was a town located in Motoyoshi District, Miyagi Prefecture, Japan': 2,
#  'Dikson is an urban locality in Taymyrsky Dolgano-Nenetsky District of Krasnoyarsk Krai, Russia': 2,
#  'Ruffled Feathers Golf Community': 2,
#  'Cadwell': 2,
#  'Hoyt': 2,
#  'Spring Township is one of nine townships in Boone County, Illinois, USA': 2,
#  "Bengassou is a town and commune in Côte d'Ivoire": 2,
#  ...}
